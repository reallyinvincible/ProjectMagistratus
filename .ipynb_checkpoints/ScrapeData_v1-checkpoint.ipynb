# %% [markdown]
# ### Scraping Tweets From Twitter

# %%
import os
import tweepy as tw
import pandas as pd

# %%
consumer_key= 'lL5jwhZjazxKKy4WUJkcRHsLb'
consumer_secret= 'r2f5XZ8f2bNtFSY72QZfdtrsNglGzIeRaHva2LoyZpVs14i0i8'
access_token= '995760376808591361-Lkl0hmd0zsjCopgGZgf4sbWppCWOYqb'
access_token_secret= 'ZMk77Ahi4s9IEfiCiK7riU7BeR6D7LG4C8o2We4pJpVa4'

# %%
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Post a tweet from Python
api.update_status("What drags me more to a #corporate sector company is #freebies, and yes, definitely #HotChocolate!")
# Your tweet has been posted!
# Out:
# Status(_api=<tweepy.api.API object at 0x7fd2ccd386d8>, _json={'created_at': 'Mon Mar 09 18:10:48 +0000 2020', 'id': 1237078399346077697, 'id_str': '1237078399346077697', 'text': 'What drags me more to a #corporate sector company is #freebies, and yes, definitely #HotChocolate!', 'truncated': False, 'entities': {'hashtags': [{'text': 'corporate', 'indices': [24, 34]}, {'text': 'freebies', 'indices': [53, 62]}, {'text': 'HotChocolate', 'indices': [84, 97]}], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://github.com/DeveloperAbhirupa" rel="nofollow">CrimeAnalysis01</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 995760376808591361, 'id_str': '995760376808591361', 'name': 'Abhirupa', 'screen_name': 'Abhirupa10', 'location': 'Vellore, India', 'description': 'Frontend Web Developer | Blockchain Enthusiast | Core-committee member IEEE VIT SB |  Developer Student Club', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 90, 'listed_count': 0, 'created_at': 'Sun May 13 20:19:08 +0000 2018', 'favourites_count': 12, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 6, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/995761478585102336/0TjD00n1_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/995761478585102336/0TjD00n1_normal.jpg', 'profile_link_color': 'FF691F', 'profile_sidebar_border_color': '000000', 'profile_sidebar_fill_color': '000000', 'profile_text_color': '000000', 'profile_use_background_image': False, 'has_extended_profile': True, 'default_profile': False, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none'}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2020, 3, 9, 18, 10, 48), id=1237078399346077697, id_str='1237078399346077697', text='What drags me more to a #corporate sector company is #freebies, and yes, definitely #HotChocolate!', truncated=False, entities={'hashtags': [{'text': 'corporate', 'indices': [24, 34]}, {'text': 'freebies', 'indices': [53, 62]}, {'text': 'HotChocolate', 'indices': [84, 97]}], 'symbols': [], 'user_mentions': [], 'urls': []}, source='CrimeAnalysis01', source_url='https://github.com/DeveloperAbhirupa', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x7fd2ccd386d8>, _json={'id': 995760376808591361, 'id_str': '995760376808591361', 'name': 'Abhirupa', 'screen_name': 'Abhirupa10', 'location': 'Vellore, India', 'description': 'Frontend Web Developer | Blockchain Enthusiast | Core-committee member IEEE VIT SB |  Developer Student Club', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 2, 'friends_count': 90, 'listed_count': 0, 'created_at': 'Sun May 13 20:19:08 +0000 2018', 'favourites_count': 12, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 6, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': '000000', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',  ...

# %% [markdown]
# ### Collecting Tweets since 3rd Jan,2020

# %%
#search_words = "#murder"
date_since = "2020-03-01"

# Collect tweets
tweets = tw.Cursor(api.search,q="#* -filter:retweets",lang="en",since=date_since).items(10)


tweet_details = [[tweet.user.screen_name, tweet.user.location, tweet.text] for tweet in tweets]
tweet_data = pd.DataFrame(data=tweet_details, columns=['User', "Location","Tweet"])

tweet_data
# Out:
#               User           Location  \
# 0           atxleb
# 1   ShayneOfficial
# 2       ManuZingar
# 3  TheLockEmUpJMan
# 4        ScootaBae  Acton, California
# 5        bunnywxzz
# 6     Shannonhill_
# 7    CardiBulgaria
# 8    FinessedaTpre
# 9  sihle_mashologu           Mthatha
#
#                                                Tweet
# 0  @theinstantwin @JKDAnthony10 @grantstern @TheD...
# 1  @SailorZZtar It’s actually cheaper to eat on t...
# 2  @tedlieu The same thing can be said of you as ...
# 3  👇🏼I see nothing but facts! https://t.co/9Xgw5R...
# 4  "Omg we lost an hour on international womans d...
# 5                          @bbymochimini Me too :(((
# 6         I’m so tired of being tired of being tired
# 7            @cardisexual It still works wtffhfgeyds
# 8                   I’m dead https://t.co/u25ePn2pkb
# 9                  @TheRealAnnabel_ Thats normal mos

# %% [markdown]
# ### Tweepy allows an extraction of 100 tweets in 70 second, extracting a total of 10000 tweets, with a appropriate sleep time

# %%
import time

#search_words = "#murder"
date_since = "2020-03-03"

# Collect tweets
'''If I want a set of 50000 tweets, '''
count=0
while count!=10000:
    print("Count: ",count,"  : ")
    count=count+1;
    tweets = tw.Cursor(api.search,q="#* -filter:retweets",lang="en",since=date_since).items(10)
    tweet_details0 = [[tweet.user.screen_name, tweet.user.location, tweet.text] for tweet in tweets]
    tweet_details.extend(tweet_details0)
    print(len(tweet_details),"\n")
    time.sleep(7) #Sleep loop for 70 sec estimating 100 tweeys in 70 seconds
# Out:
# Count:  0   :
# 6780
#
# Count:  1   :
# 6790
#
# Count:  2   :
# 6800
#
# Count:  3   :
# 6810
#
# Count:  4   :
# 6820
#
# Count:  5   :
# 6830
#
# Count:  6   :
# 6840
#
# Count:  7   :
# 6850
#
# Count:  8   :
# 6860
#
# Count:  9   :
# 6870
#
# Count:  10   :
# 6880
#
# Count:  11   :
# 6890
#
# Count:  12   :
# 6900
#
# Count:  13   :
# 6910
#
# Count:  14   :
# 6920
#
# Count:  15   :
# 6930
#
# Count:  16   :
# 6940
#
# Count:  17   :
# 6950
#
# Count:  18   :
# 6960
#
# Count:  19   :
# 6970
#
# Count:  20   :
# 6980
#
# Count:  21   :
# 6990
#
# Count:  22   :
# 7000
#
# Count:  23   :
# 7010
#
# Count:  24   :
# 7020
#
# Count:  25   :
# 7030
#
# Count:  26   :
# 7040
#
# Count:  27   :
# 7050
#
# Count:  28   :
# 7060
#
# Count:  29   :
# 7070
#
# Count:  30   :
# 7080
#
# Count:  31   :
# 7090
#
# Count:  32   :
# 7100
#
# Count:  33   :
# 7110
#
# Count:  34   :
# 7120
#
# Count:  35   :
# 7130
#
# Count:  36   :
# 7140
#
# Count:  37   :
# 7150
#
# Count:  38   :
# 7160
#
# Count:  39   :
# 7170
#
# Count:  40   :
# 7180
#
# Count:  41   :
# 7190
#
# Count:  42   :
# 7200
#
# Count:  43   :
# 7210
#
# Count:  44   :
# 7220
#
# Count:  45   :
# 7230
#
# Count:  46   :
# 7240
#
# Count:  47   :
# 7250
#
# Count:  48   :
# 7260
#
# Count:  49   :
# 7270
#
# Count:  50   :
# 7280
#
# Count:  51   :
# 7290
#
# Count:  52   :
# 7300
#
# Count:  53   :
# 7310
#
# Count:  54   :
# 7320
#
# Count:  55   :
# 7330
#
# Count:  56   :
# 7340
#
# Count:  57   :
# 7350
#
# Count:  58   :
# 7360
#
# Count:  59   :
# 7370
#
# Count:  60   :
# 7380
#
# Count:  61   :
# 7390
#
# Count:  62   :
# 7400
#
# Count:  63   :
# 7410
#
# Count:  64   :
# 7420
#
# Count:  65   :
# 7430
#
# Count:  66   :
# 7440
#
# Count:  67   :
# 7450
#
# Count:  68   :
# 7460
#
# Count:  69   :
# 7470
#
# Count:  70   :
# 7480
#
# Count:  71   :
# 7490
#
# Count:  72   :
# 7500
#
# Count:  73   :
# 7510
#
# Count:  74   :
# 7520
#
# Count:  75   :
# 7530
#
# Count:  76   :
# 7540
#
# Count:  77   :
# 7550
#
# Count:  78   :
# 7560
#
# Count:  79   :
# 7570
#
# Count:  80   :
# 7580
#
# Count:  81   :
# 7590
#
# Count:  82   :
# 7600
#
# Count:  83   :
# 7610
#
# Count:  84   :
# 7620
#
# Count:  85   :
# 7630
#
# Count:  86   :
# 7640
#
# Count:  87   :
# 7650
#
# Count:  88   :
# 7660
#
# Count:  89   :
# 7670
#
# Count:  90   :
# 7680
#
# Count:  91   :
# 7690
#
# Count:  92   :
# 7700
#
# Count:  93   :
# 7710
#
# Count:  94   :
# 7720
#
# Count:  95   :
# 7730
#
# Count:  96   :
# 7740
#
# Count:  97   :
# 7750
#
# Count:  98   :
# 7760
#
# Count:  99   :
# 7770
#
# Count:  100   :
# 7780
#
# Count:  101   :
# 7790
#
# Count:  102   :
# 7800
#
# Count:  103   :
# 7810
#
# Count:  104   :
# 7820
#
# Count:  105   :
# 7830
#
# Count:  106   :
# 7840
#
# Count:  107   :
# 7850
#
# Count:  108   :
# 7860
#
# Count:  109   :
# 7870
#
# Count:  110   :
# 7880
#
# Count:  111   :
# 7890
#
# Count:  112   :
# 7900
#
# Count:  113   :
# 7910
#
# Count:  114   :
# 7920
#
# Count:  115   :
# 7930
#
# Count:  116   :
# 7940
#
# Count:  117   :
# 7950
#
# Count:  118   :
# 7960
#
# Count:  119   :
# 7970
#
# Count:  120   :
# 7980
#
# Count:  121   :
# 7990
#
# Count:  122   :
# 8000
#
# Count:  123   :
# 8010
#
# Count:  124   :
# 8020
#
# Count:  125   :
# 8030
#
# Count:  126   :
# 8040
#
# Count:  127   :
# 8050
#
# Count:  128   :
# 8060
#
# Count:  129   :
# 8070
#
# Count:  130   :
# 8080
#
# Count:  131   :
# 8090
#
# Count:  132   :
# 8100
#
# Count:  133   :
# 8110
#
# Count:  134   :
# 8120
#
# Count:  135   :
# 8130
#
# Count:  136   :
# 8140
#
# Count:  137   :
# 8150
#
# Count:  138   :
# 8160
#
# Count:  139   :
# 8170
#
# Count:  140   :
# 8180
#
# Count:  141   :
# 8190
#
# Count:  142   :
# 8200
#
# Count:  143   :
# 8210
#
# Count:  144   :
# 8220
#
# Count:  145   :
# 8230
#
# Count:  146   :
# 8240
#
# Count:  147   :
# 8250
#
# Count:  148   :
# 8260
#
# Count:  149   :
# 8270
#
# Count:  150   :
# 8280
#
# Count:  151   :
# 8290
#
# Count:  152   :
# 8300
#
# Count:  153   :
# 8310
#
# Count:  154   :
# 8320
#
# Count:  155   :
# 8330
#
# Count:  156   :
# 8340
#
# Count:  157   :
# 8350
#
# Count:  158   :
# 8360
#
# Count:  159   :
# 8370
#
# Count:  160   :
# 8380
#
# Count:  161   :
# 8390
#
# Count:  162   :
# 8400
#
# Count:  163   :
# 8410
#
# Count:  164   :
# 8420
#
# Count:  165   :
# 8430
#
# Count:  166   :
# 8440
#
# Count:  167   :
# 8450
#
# Count:  168   :
# 8460
#
# Count:  169   :
# 8470
#
# Count:  170   :
# 8480
#
# Count:  171   :
# 8490
#
# Count:  172   :
# 8500
#
# Count:  173   :
# 8510
#
# Count:  174   :
# 8520
#
# Count:  175   :
# 8530
#
# Count:  176   :
# 8540
#
# Count:  177   :
# 8550
#
# Count:  178   :
# 8560
#
# Count:  179   :
# 8570
#
# Count:  180   :
# 8580
#
# Count:  181   :
# 8590
#
# Count:  182   :
# 8600
#
# Count:  183   :
# 8610
#
# Count:  184   :
# 8620
#
# Count:  185   :
# 8630
#
# Count:  186   :
# 8640
#
# Count:  187   :
# 8650
#
# Count:  188   :
# 8660
#
# Count:  189   :
# 8670
#
# Count:  190   :
# 8680
#
# Count:  191   :
# 8690
#
# Count:  192   :
# 8700
#
# Count:  193   :
# 8710
#
# Count:  194   :
# 8720
#
# Count:  195   :
# 8730
#
# Count:  196   :
# 8740
#
# Count:  197   :
# 8750
#
# Count:  198   :
# 8760
#
# Count:  199   :
# 8770
#
# Count:  200   :
# 8780
#
# Count:  201   :
# 8790
#
# Count:  202   :
# 8800
#
# Count:  203   :
# 8810
#
# Count:  204   :
# 8820
#
# Count:  205   :
# 8830
#
# Count:  206   :
# 8840
#
# Count:  207   :
# 8850
#
# Count:  208   :
# 8860
#
# Count:  209   :
# 8870
#
# Count:  210   :
# 8880
#
# Count:  211   :
# 8890
#
# Count:  212   :
# 8900
#
# Count:  213   :
# 8910
#
# Count:  214   :
# 8920
#
# Count:  215   :
# 8930
#
# Count:  216   :
# 8940
#
# Count:  217   :
# 8950
#
# Count:  218   :
# 8960
#
# Count:  219   :
# 8970
#
# Count:  220   :
# 8980
#
# Count:  221   :
# 8990
#
# Count:  222   :
# 9000
#
# Count:  223   :
# 9010
#
# Count:  224   :
# 9020
#
# Count:  225   :
# 9030
#
# Count:  226   :
# 9040
#
# Count:  227   :
# 9050
#
# Count:  228   :
# 9060
#
# Count:  229   :
# 9070
#
# Count:  230   :
# 9080
#
# Count:  231   :
# 9090
#
# Count:  232   :
# 9100
#
# Count:  233   :
# 9110
#
# Count:  234   :
# 9120
#
# Count:  235   :
# 9130
#
# Count:  236   :
# 9140
#
# Count:  237   :
# 9150
#
# Count:  238   :
# 9160
#
# Count:  239   :
# 9170
#
# Count:  240   :
# 9180
#
# Count:  241   :
# 9190
#
# Count:  242   :
# 9200
#
# Count:  243   :
# 9210
#
# Count:  244   :
# 9220
#
# Count:  245   :
# 9230
#
# Count:  246   :
# 9240
#
# Count:  247   :
# 9250
#
# Count:  248   :
# 9260
#
# Count:  249   :
# 9270
#
# Count:  250   :
# 9280
#
# Count:  251   :
# 9290
#
# Count:  252   :
# 9300
#
# Count:  253   :
# 9310
#
# Count:  254   :
# 9320
#
# Count:  255   :
# 9330
#
# Count:  256   :
# 9340
#
# Count:  257   :
# 9350
#
# Count:  258   :
# 9360
#
# Count:  259   :
# 9370
#
# Count:  260   :
# 9380
#
# Count:  261   :
# 9390
#
# Count:  262   :
# 9400
#
# Count:  263   :
# 9410
#
# Count:  264   :
# 9420
#
# Count:  265   :
# 9430
#
# Count:  266   :
# 9440
#
# Count:  267   :
# 9450
#
# Count:  268   :
# 9460
#
# Count:  269   :
# 9470
#
# Count:  270   :
# 9480
#
# Count:  271   :
# 9490
#
# Count:  272   :
# 9500
#
# Count:  273   :
# 9510
#
# Count:  274   :
# 9520
#
# Count:  275   :
# 9530
#
# Count:  276   :
# 9540
#
# Count:  277   :
# 9550
#
# Count:  278   :
# 9560
#
# Count:  279   :
# 9570
#
# Count:  280   :
# 9580
#
# Count:  281   :
# 9590
#
# Count:  282   :
# 9600
#
# Count:  283   :
# 9610
#
# Count:  284   :
# 9620
#
# Count:  285   :
# 9630
#
# Count:  286   :
# 9640
#
# Count:  287   :
# 9650
#
# Count:  288   :
# 9660
#
# Count:  289   :
# 9670
#
# Count:  290   :
# 9680
#
# Count:  291   :
# 9690
#
# Count:  292   :
# 9700
#
# Count:  293   :
# 9710
#
# Count:  294   :
# 9720
#
# Count:  295   :
# 9730
#
# Count:  296   :
# 9740
#
# Count:  297   :
# 9750
#
# Count:  298   :
# 9760
#
# Count:  299   :
# 9770
#
# Count:  300   :
# 9780
#
# Count:  301   :
# 9790
#
# Count:  302   :
# 9800
#
# Count:  303   :
# 9810
#
# Count:  304   :
# 9820
#
# Count:  305   :
# 9830
#
# Count:  306   :
# 9840
#
# Count:  307   :
# 9850
#
# Count:  308   :
# 9860
#
# Count:  309   :
# 9870
#
# Count:  310   :
# 9880
#
# Count:  311   :
# 9890
#
# Count:  312   :
# 9900
#
# Count:  313   :
# 9910
#
# Count:  314   :
# 9920
#
# Count:  315   :
# 9930
#
# Count:  316   :
# 9940
#
# Count:  317   :
# 9950
#
# Count:  318   :
# 9960
#
# Count:  319   :
# 9970
#
# Count:  320   :
# 9980
#
# Count:  321   :
# 9990
#
# Count:  322   :
# 10000
#
# Count:  323   :
# 10010
#
# Count:  324   :
# 10020
#
# Count:  325   :
# 10030
#
# Count:  326   :
# 10040
#
# Count:  327   :
# 10050
#
# Count:  328   :
# 10060
#
# Count:  329   :
# 10070
#
# Count:  330   :
# 10080
#
# Count:  331   :
# 10090
#
# Count:  332   :
# 10100
#
# Count:  333   :
# 10110
#
# Count:  334   :
# 10120
#
# Count:  335   :
# 10130
#
# Count:  336   :
# 10140
#
# Count:  337   :
# 10150
#
# Count:  338   :
# 10160
#
# Count:  339   :
# 10170
#
# Count:  340   :
# 10180
#
# Count:  341   :
# 10190
#
# Count:  342   :
# 10200
#
# Count:  343   :
# 10210
#
# Count:  344   :
# 10220
# Count:  345   :
# 10230
#
# Count:  346   :
# 10240
#
# Count:  347   :
# 10250
#
# Count:  348   :
# 10260
#
# Count:  349   :
# 10270
#
# Count:  350   :
# 10280
#
# Count:  351   :
# 10290
#
# Count:  352   :
# 10300
#
# Count:  353   :
# 10310
#
# Count:  354   :
# 10320
#
# Count:  355   :
# 10330
#
# Count:  356   :
# 10340
#
# Count:  357   :
# 10350
#
# Count:  358   :
# 10360
#
# Count:  359   :
# 10370
#
# Count:  360   :
# 10380
#
# Count:  361   :
# 10390
#
# Count:  362   :
# 10400
#
# Count:  363   :
# 10410
#
# Count:  364   :
# 10420
#
# Count:  365   :
# 10430
#
# Count:  366   :
# 10440
#
# Count:  367   :
# 10450
#
# Count:  368   :
# 10460
#
# Count:  369   :
# 10470
#
# Count:  370   :
# 10480
#
# Count:  371   :
# 10490
#
# Count:  372   :
# 10500
#
# Count:  373   :
# 10510
#
# Count:  374   :
# 10520
#
# Count:  375   :
# 10530
#
# Count:  376   :
# 10540
#
# Count:  377   :
# 10550
#
# Count:  378   :
# 10560
#
# Count:  379   :
# 10570
#
# Count:  380   :
# 10580
#
# Count:  381   :
# 10590
#
# Count:  382   :
# 10600
#
# Count:  383   :
# 10610
#
# Count:  384   :
# 10620
#
# Count:  385   :
# 10630
#
# Count:  386   :
# 10640
#
# Count:  387   :
# 10650
#
# Count:  388   :
# 10660
#
# Count:  389   :
# 10670
#
# Count:  390   :
# 10680
#
# Count:  391   :
# 10690
#
# Count:  392   :
# 10700
#
# Count:  393   :
# 10710
#
# Count:  394   :
# 10720
#
# Count:  395   :
# 10730
#
# Count:  396   :
# 10740
#
# Count:  397   :
# 10750
#
# Count:  398   :
# 10760
#
# Count:  399   :
# 10770
#
# Count:  400   :
# 10780
#
# Count:  401   :
# 10790
#
# Count:  402   :
# 10800
#
# Count:  403   :
# 10810
#
# Count:  404   :
# 10820
#
# Count:  405   :
# 10830
#
# Count:  406   :
# 10840
#
# Count:  407   :
# 10850
#
# Count:  408   :
# 10860
#
# Count:  409   :
# 10870
#
# Count:  410   :
# 10880
#
# Count:  411   :
# 10890
#
# Count:  412   :
# 10900
#
# Count:  413   :
# 10910
#
# Count:  414   :
# 10920
#
# Count:  415   :
# 10930
#
# Count:  416   :
# 10940
#
# Count:  417   :
# 10950
#
# Count:  418   :
# 10960
#
# Count:  419   :
# 10970
#
# Count:  420   :
# 10980
#
# Count:  421   :
# 10990
#
# Count:  422   :
# 11000
#
# Count:  423   :
# 11010
#
# Count:  424   :
# 11020
#
# Count:  425   :
# 11030
#
# Count:  426   :
# 11040
#
# Count:  427   :
# 11050
#
# Count:  428   :
# 11060
#
# Count:  429   :
# 11070
#
# Count:  430   :
# 11080
#
# Count:  431   :
# 11090
#
# Count:  432   :
# 11100
#
# Count:  433   :
# 11110
#
# Count:  434   :
# 11120
#
# Count:  435   :
# 11130
#
# Count:  436   :
# 11140
#
# Count:  437   :
# 11150
#
# Count:  438   :
# 11160
#
# Count:  439   :
# 11170
#
# Count:  440   :
# 11180
#
# Count:  441   :
# 11190
#
# Count:  442   :
# 11200
#
# Count:  443   :
# 11210
#
# Count:  444   :
# 11220
#
# Count:  445   :
# 11230
#
# Count:  446   :
# 11240
#
# Count:  447   :
# 11250
#
# Count:  448   :
# 11260
#
# Count:  449   :
# 11270
#
# Count:  450   :
# 11280
#
# Count:  451   :
# 11290
#
# Count:  452   :
# 11300
#
# Count:  453   :
# 11310
#
# Count:  454   :
# 11320
#
# Count:  455   :
# 11330
#
# Count:  456   :
# 11340
#
# Count:  457   :
# 11350
#
# Count:  458   :
# 11360
#
# Count:  459   :
# 11370
#
# Count:  460   :
# 11380
#
# Count:  461   :
# 11390
#
# Count:  462   :
# 11400
#
# Count:  463   :
# 11410
#
# Count:  464   :
# 11420
#
# Count:  465   :
# 11430
#
# Count:  466   :
# 11440
#
# Count:  467   :
# 11450
#
# Count:  468   :
# 11460
#
# Count:  469   :
# 11470
#
# Count:  470   :
# 11480
#
# Count:  471   :
# 11490
#
# Count:  472   :
# 11500
#
# Count:  473   :
# 11510
#
# Count:  474   :
# 11520
#
# Count:  475   :
# 11530
#
# Count:  476   :
# 11540
#
# Count:  477   :
# 11550
#
# Count:  478   :
# 11560
#
# Count:  479   :
# 11570
#
# Count:  480   :
# 11580
#
# Count:  481   :
# 11590
#
# Count:  482   :
# 11600
#
# Count:  483   :
# 11610
#
# Count:  484   :
# 11620
#
# Count:  485   :
# 11630
#
# Count:  486   :
# 11640
#
# Count:  487   :
# 11650
#
# Count:  488   :
# 11660
#
# Count:  489   :
# 11670
#
# Count:  490   :
# 11680
#
# Count:  491   :
# 11690
#
# Count:  492   :
# 11700
#
# Count:  493   :
# 11710
#
# Count:  494   :
# 11720
#
# Count:  495   :
# 11730
#
# Count:  496   :
# 11740
#
# Count:  497   :
# 11750
#
# Count:  498   :
# 11760
#
# Count:  499   :
# 11770
#
# Count:  500   :
# 11780
#
# Count:  501   :
# 11790
#
# Count:  502   :
# 11800
#
# Count:  503   :
# 11810
#
# Count:  504   :
# 11820
#
# Count:  505   :
# 11830
#
# Count:  506   :
# 11840
#
# Count:  507   :
# 11850
#
# Count:  508   :
# 11860
#
# Count:  509   :
# 11870
#
# Count:  510   :
# 11880
#
# Count:  511   :
# 11890
#
# Count:  512   :
# 11900
#
# Count:  513   :
# 11910
#
# Count:  514   :
# 11920
#
# Count:  515   :
# 11930
#
# Count:  516   :
# 11940
#
# Count:  517   :
# 11950
#
# Count:  518   :
# 11960
#
# Count:  519   :
# 11970
#
# Count:  520   :
# 11980
#
# Count:  521   :
# 11990
#
# Count:  522   :
# 12000
#
# Count:  523   :
# 12010
#
# Count:  524   :
# 12020
#
# Count:  525   :
# 12030
#
# Count:  526   :
# 12040
#
# Count:  527   :
# 12050
#
# Count:  528   :
# 12060
#
# Count:  529   :
# 12070
#
# Count:  530   :
# 12080
#
# Count:  531   :
# 12090
#
# Count:  532   :
# 12100
#
# Count:  533   :
# 12110
#
# Count:  534   :
# 12120
#
# Count:  535   :
# 12130
#
# Count:  536   :
# 12140
#
# Count:  537   :
# 12150
#
# Count:  538   :
# 12160
#
# Count:  539   :
# 12170
#
# Count:  540   :
# 12180
#
# Count:  541   :
# 12190
#
# Count:  542   :
# 12200
#
# Count:  543   :
# 12210
#
# Count:  544   :
# 12220
#
# Count:  545   :
# 12230
#
# Count:  546   :
# 12240
#
# Count:  547   :
# 12250
#
# Count:  548   :
# 12260
#
# Count:  549   :
# 12270
#
# Count:  550   :
# 12280
#
# Count:  551   :
# 12290
#
# Count:  552   :
# 12300
#
# Count:  553   :
# 12310
#
# Count:  554   :
# 12320
#
# Count:  555   :
# 12330
#
# Count:  556   :
# 12340
#
# Count:  557   :
# 12350
#
# Count:  558   :
# 12360
#
# Count:  559   :
# 12370
#
# Count:  560   :
# 12380
#
# Count:  561   :
# 12390
#
# Count:  562   :
# 12400
#
# Count:  563   :
# 12410
#
# Count:  564   :
# 12420
#
# Count:  565   :
# 12430
#
# Count:  566   :
# 12440
#
# Count:  567   :
# 12450
#
# Count:  568   :
# 12460
#
# Count:  569   :
# 12470
#
# Count:  570   :
# 12480
#
# Count:  571   :
# 12490
#
# Count:  572   :
# 12500
#
# Count:  573   :
# 12510
#
# Count:  574   :
# 12520
#
# Count:  575   :
# 12530
#
# Count:  576   :
# 12540
#
# Count:  577   :
# 12550
#
# Count:  578   :
# 12560
#
# Count:  579   :
# 12570
#
# Count:  580   :
# 12580
#
# Count:  581   :
# 12590
#
# Count:  582   :
# 12600
#
# Count:  583   :
# 12610
#
# Count:  584   :
# 12620
#
# Count:  585   :
# 12630
#
# Count:  586   :
# 12640
#
# Count:  587   :
# 12650
#
# Count:  588   :
# 12660
#
# Count:  589   :
# 12670
#
# Count:  590   :
# 12680
#
# Count:  591   :
# 12690
#
# Count:  592   :
# 12700
#
# Count:  593   :
# 12710
#
# Count:  594   :
# 12720
#
# Count:  595   :
# 12730
#
# Count:  596   :
# 12740
#
# Count:  597   :
# 12750
#
# Count:  598   :
# 12760
#
# Count:  599   :
# 12770
#
# Count:  600   :
# 12780
#
# Count:  601   :
# 12790
#
# Count:  602   :
# 12800
#
# Count:  603   :
# 12810
#
# Count:  604   :
# 12820
#
# Count:  605   :
# 12830
#
# Count:  606   :
# 12840
#
# Count:  607   :
# 12850
#
# Count:  608   :
# 12860
#
# Count:  609   :
# 12870
#
# Count:  610   :
# 12880
#
# Count:  611   :
# 12890
#
# Count:  612   :
# 12900
#
# Count:  613   :
# 12910
#
# Count:  614   :
# 12920
#
# Count:  615   :
# 12930
#
# Count:  616   :
# 12940
#
# Count:  617   :
# 12950
#
# Count:  618   :
# 12960
#
# Count:  619   :
# 12970
#
# Count:  620   :
# 12980
#
# Count:  621   :
# 12990
#
# Count:  622   :
# 13000
#
# Count:  623   :
# 13010
#
# Count:  624   :
# 13020
#
# Count:  625   :
# 13030
#
# Count:  626   :
# 13040
#
# Count:  627   :
# 13050
#
# Count:  628   :
# 13060
#
# Count:  629   :
# 13070
#
# Count:  630   :
# 13080
#
# Count:  631   :
# 13090
#
# Count:  632   :
# 13100
#
# Count:  633   :
# 13110
#
# Count:  634   :
# 13120
#
# Count:  635   :
# 13130
#
# Count:  636   :
# 13140
#
# Count:  637   :
# 13150
#
# Count:  638   :
# 13160
#
# Count:  639   :
# 13170
#
# Count:  640   :
# 13180
#
# Count:  641   :
# 13190
#
# Count:  642   :
# 13200
#
# Count:  643   :
# 13210
#
# Count:  644   :
# 13220
#
# Count:  645   :
# 13230
#
# Count:  646   :
# 13240
#
# Count:  647   :
# 13250
#
# Count:  648   :
# 13260
#
# Count:  649   :
# 13270
#
# Count:  650   :
# 13280
#
# Count:  651   :
# 13290
#
# Count:  652   :
# 13300
#
# Count:  653   :
# 13310
#
# Count:  654   :
# 13320
#
# Count:  655   :
# 13330
#
# Count:  656   :
# 13340
#
# Count:  657   :
# 13350
#
# Count:  658   :
# 13360
#
# Count:  659   :
# 13370
#
# Count:  660   :
# 13380
#
# Count:  661   :
# 13390
#
# Count:  662   :
# 13400
#
# Count:  663   :
# 13410
#
# Count:  664   :
# 13420
#
# Count:  665   :
# 13430
#
# Count:  666   :
# 13440
#
# Count:  667   :
# 13450
#
# Count:  668   :
# 13460
#
# Count:  669   :
# 13470
#
# Count:  670   :
# 13480
#
# Count:  671   :
# 13490
#
# Count:  672   :
# 13500
# Count:  673   :
# 13510
#
# Count:  674   :
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     158             conn = connection.create_connection(
# --> 159                 (self._dns_host, self.port), self.timeout, **extra_kw)
#     160
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      79     if err is not None:
# ---> 80         raise err
#      81
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      69                 sock.bind(source_address)
# ---> 70             sock.connect(sa)
#      71             return sock
#
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     342         try:
# --> 343             self._validate_conn(conn)
#     344         except (SocketTimeout, BaseSSLError) as e:
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#     838         if not getattr(conn, 'sock', None):  # AppEngine might not have  `.sock`
# --> 839             conn.connect()
#     840
#
# ~/.local/lib/python3.6/site-packages/urllib3/connection.py in connect(self)
#     300         # Add certificate verification
# --> 301         conn = self._new_conn()
#     302         hostname = self.host
#
# ~/.local/lib/python3.6/site-packages/urllib3/connection.py in _new_conn(self)
#     167             raise NewConnectionError(
# --> 168                 self, "Failed to establish a new connection: %s" % e)
#     169
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x7fd2980c8278>: Failed to establish a new connection: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#
# ~/.local/lib/python3.6/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     637             retries = retries.increment(method, url, error=e, _pool=self,
# --> 638                                         _stacktrace=sys.exc_info()[2])
#     639             retries.sleep()
#
# ~/.local/lib/python3.6/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     397         if new_retry.is_exhausted():
# --> 398             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     399
#
# MaxRetryError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=%23%2A+-filter%3Aretweets&lang=en&since=2020-03-03 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fd2980c8278>: Failed to establish a new connection: [Errno 101] Network is unreachable',))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#
# ConnectionError: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=%23%2A+-filter%3Aretweets&lang=en&since=2020-03-03 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fd2980c8278>: Failed to establish a new connection: [Errno 101] Network is unreachable',))
#
# During handling of the above exception, another exception occurred:
#
# TweepError                                Traceback (most recent call last)
# <ipython-input-79-138afb79ff90> in <module>
#      11     count=count+1;
#      12     tweets = tw.Cursor(api.search,q="#* -filter:retweets",lang="en",since=date_since).items(10)
# ---> 13     tweet_details0 = [[tweet.user.screen_name, tweet.user.location, tweet.text] for tweet in tweets]
#      14     tweet_details.extend(tweet_details0)
#      15     print(len(tweet_details),"\n")
#
# <ipython-input-79-138afb79ff90> in <listcomp>(.0)
#      11     count=count+1;
#      12     tweets = tw.Cursor(api.search,q="#* -filter:retweets",lang="en",since=date_since).items(10)
# ---> 13     tweet_details0 = [[tweet.user.screen_name, tweet.user.location, tweet.text] for tweet in tweets]
#      14     tweet_details.extend(tweet_details0)
#      15     print(len(tweet_details),"\n")
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in __next__(self)
#      45
#      46     def __next__(self):
# ---> 47         return self.next()
#      48
#      49     def next(self):
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     193         if self.current_page is None or self.page_index == len(self.current_page) - 1:
#     194             # Reached end of current page, get the next page...
# --> 195             self.current_page = self.page_iterator.next()
#     196             self.page_index = -1
#     197         self.page_index += 1
#
# ~/.local/lib/python3.6/site-packages/tweepy/cursor.py in next(self)
#     104
#     105         if self.index >= len(self.results) - 1:
# --> 106             data = self.method(max_id=self.max_id, parser=RawParser(), *self.args, **self.kargs)
#     107
#     108             if hasattr(self.method, '__self__'):
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in _call(*args, **kwargs)
#     248                 return method
#     249             else:
# --> 250                 return method.execute()
#     251         finally:
#     252             method.session.close()
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
# --> 191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#     192
#     193                 rem_calls = resp.headers.get('x-rate-limit-remaining')
#
# ~/.local/lib/python3.6/site-packages/six.py in reraise(tp, value, tb)
#     690                 value = tp()
#     691             if value.__traceback__ is not tb:
# --> 692                 raise value.with_traceback(tb)
#     693             raise value
#     694         finally:
#
# ~/.local/lib/python3.6/site-packages/tweepy/binder.py in execute(self)
#     187                                                 timeout=self.api.timeout,
#     188                                                 auth=auth,
# --> 189                                                 proxies=self.api.proxy)
#     190                 except Exception as e:
#     191                     six.reraise(TweepError, TweepError('Failed to send request: %s' % e), sys.exc_info()[2])
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# ~/.local/lib/python3.6/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# ~/.local/lib/python3.6/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     514                 raise SSLError(e, request=request)
#     515
# --> 516             raise ConnectionError(e, request=request)
#     517
#     518         except ClosedPoolError as e:
#
# TweepError: Failed to send request: HTTPSConnectionPool(host='api.twitter.com', port=443): Max retries exceeded with url: /1.1/search/tweets.json?q=%23%2A+-filter%3Aretweets&lang=en&since=2020-03-03 (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x7fd2980c8278>: Failed to establish a new connection: [Errno 101] Network is unreachable',))

# %%
tweet_data = pd.DataFrame(data=tweet_details, columns=['User', "Location","Tweet"])
tweet_data
# Out:
#                   User           Location  \
# 0               atxleb
# 1       ShayneOfficial
# 2           ManuZingar
# 3      TheLockEmUpJMan
# 4            ScootaBae  Acton, California
# ...                ...                ...
# 13505     onceyougoBTS
# 13506         Dlocomix
# 13507        KerryKCee
# 13508        tinecruzz
# 13509  Davheedoffocial
#
#                                                    Tweet
# 0      @theinstantwin @JKDAnthony10 @grantstern @TheD...
# 1      @SailorZZtar It’s actually cheaper to eat on t...
# 2      @tedlieu The same thing can be said of you as ...
# 3      👇🏼I see nothing but facts! https://t.co/9Xgw5R...
# 4      "Omg we lost an hour on international womans d...
# ...                                                  ...
# 13505                            @imyourseesaw Morning 🥺
# 13506  @cassiebearbear1 I'm gonna need you to not cau...
# 13507        @MisterAlbie I'm not in the mood for jokes.
# 13508                           i will always pray for u
# 13509                         @BigMan_Xander Money heist
#
# [13510 rows x 3 columns]

# %%
tweet_data.to_csv('tweet_data1.csv')

# %%
import json
with open('data.json', 'w') as outfile:
    json.dump({'contentItems': tweet_details}, outfile,indent=4)

# %% [markdown]
# ### Converting all tweets thus collected into a IBM Watson acceptable JSON format

# %%
#create a list of dictionaries to later import it into json format that is accepted by Watson
df=tweet_data
d={}#The dictionary
dlist=[]#The list to append the dictionary to

for i in df.itertuples():
    d={}
    d['content']=i[3]
    d['contenttype']="text/plain"
    d['created']= 0
    d['id']= i[0]
    d['language']= "en"
    dlist.append(d)
    print(d,"\n")
# Out:
# {'content': '@theinstantwin @JKDAnthony10 @grantstern @TheDemCoalition Because they’d be prosecuting government officials?', 'contenttype': 'text/plain', 'created': 0, 'id': 0, 'language': 'en'}
#
# {'content': '@SailorZZtar It’s actually cheaper to eat on the right. That’s multiple days worth of food. The McD’s is just one meal during the day', 'contenttype': 'text/plain', 'created': 0, 'id': 1, 'language': 'en'}
#
# {'content': '@tedlieu The same thing can be said of you as you attended AIPAC, where one attendee, and likely others, were and w… https://t.co/pgLaDT5IgS', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}
#
# {'content': '👇🏼I see nothing but facts! https://t.co/9Xgw5RVmNU', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}
#
# {'content': '"Omg we lost an hour on international womans day." Omfg shut up. Daylights savings time is not always on internatio… https://t.co/36cVsIqlfb', 'contenttype': 'text/plain', 'created': 0, 'id': 4, 'language': 'en'}
#
# {'content': '@bbymochimini Me too :(((', 'contenttype': 'text/plain', 'created': 0, 'id': 5, 'language': 'en'}
#
# {'content': 'I’m so tired of being tired of being tired', 'contenttype': 'text/plain', 'created': 0, 'id': 6, 'language': 'en'}
#
# {'content': '@cardisexual It still works wtffhfgeyds', 'contenttype': 'text/plain', 'created': 0, 'id': 7, 'language': 'en'}
#
# {'content': 'I’m dead https://t.co/u25ePn2pkb', 'contenttype': 'text/plain', 'created': 0, 'id': 8, 'language': 'en'}
#
# {'content': '@TheRealAnnabel_ Thats normal mos', 'contenttype': 'text/plain', 'created': 0, 'id': 9, 'language': 'en'}
#
# {'content': 'hatchet pussy be hittin different', 'contenttype': 'text/plain', 'created': 0, 'id': 10, 'language': 'en'}
#
# {'content': '@sandra_wynkoop With Cruz!', 'contenttype': 'text/plain', 'created': 0, 'id': 11, 'language': 'en'}
#
# {'content': 'Just passed by a house with their icicle lights and wreath still up.', 'contenttype': 'text/plain', 'created': 0, 'id': 12, 'language': 'en'}
#
# {'content': '@BranfordJones5 😂new day tomorrow', 'contenttype': 'text/plain', 'created': 0, 'id': 13, 'language': 'en'}
#
# {'content': '@chafin99 @DraedaVenorik @InfinityWard True! My only day off was yesterday and I wanted to level up, cause I wanna… https://t.co/OqjWFyLvLH', 'contenttype': 'text/plain', 'created': 0, 'id': 14, 'language': 'en'}
#
# {'content': 'Concerned about the #coronavirus (COVID-19)? Check out our resource page here: https://t.co/Gq0gP7WkLM https://t.co/CmONX2YQW6', 'contenttype': 'text/plain', 'created': 0, 'id': 15, 'language': 'en'}
#
# {'content': 'the starbucks barista misheard my name and now everyone in this place is gunna think my name is martha. don’t hmu😔', 'contenttype': 'text/plain', 'created': 0, 'id': 16, 'language': 'en'}
#
# {'content': 'Say it with me: namjoon prettiest boy @BTS_twt\n#iHeartAwards #BestMusicVideo #BoyWithLuv #BTSRM\nhttps://t.co/vJcQFn5BiH', 'contenttype': 'text/plain', 'created': 0, 'id': 17, 'language': 'en'}
#
# {'content': '@BeyondBeautiful Who cares', 'contenttype': 'text/plain', 'created': 0, 'id': 18, 'language': 'en'}
#
# {'content': 'Good afternoon, Cyber Defenders!! Web Recon anyone?? “Final Recon - OSINT Tool for All-In-One Web Reconnaissance”… https://t.co/vj4ZwvCBnE', 'contenttype': 'text/plain', 'created': 0, 'id': 19, 'language': 'en'}
#
# {'content': 'hatchet pussy be hittin different', 'contenttype': 'text/plain', 'created': 0, 'id': 20, 'language': 'en'}
#
# {'content': '@sandra_wynkoop With Cruz!', 'contenttype': 'text/plain', 'created': 0, 'id': 21, 'language': 'en'}
#
# {'content': 'Just passed by a house with their icicle lights and wreath still up.', 'contenttype': 'text/plain', 'created': 0, 'id': 22, 'language': 'en'}
#
# {'content': '@BranfordJones5 😂new day tomorrow', 'contenttype': 'text/plain', 'created': 0, 'id': 23, 'language': 'en'}
#
# {'content': '@chafin99 @DraedaVenorik @InfinityWard True! My only day off was yesterday and I wanted to level up, cause I wanna… https://t.co/OqjWFyLvLH', 'contenttype': 'text/plain', 'created': 0, 'id': 24, 'language': 'en'}
#
# {'content': 'Concerned about the #coronavirus (COVID-19)? Check out our resource page here: https://t.co/Gq0gP7WkLM https://t.co/CmONX2YQW6', 'contenttype': 'text/plain', 'created': 0, 'id': 25, 'language': 'en'}
#
# {'content': 'the starbucks barista misheard my name and now everyone in this place is gunna think my name is martha. don’t hmu😔', 'contenttype': 'text/plain', 'created': 0, 'id': 26, 'language': 'en'}
#
# {'content': 'Say it with me: namjoon prettiest boy @BTS_twt\n#iHeartAwards #BestMusicVideo #BoyWithLuv #BTSRM\nhttps://t.co/vJcQFn5BiH', 'contenttype': 'text/plain', 'created': 0, 'id': 27, 'language': 'en'}
#
# {'content': '@BeyondBeautiful Who cares', 'contenttype': 'text/plain', 'created': 0, 'id': 28, 'language': 'en'}
#
# {'content': 'Good afternoon, Cyber Defenders!! Web Recon anyone?? “Final Recon - OSINT Tool for All-In-One Web Reconnaissance”… https://t.co/vj4ZwvCBnE', 'contenttype': 'text/plain', 'created': 0, 'id': 29, 'language': 'en'}
#
# {'content': '@dar_ruga @EstherBirungi4 Equity not equality would make more sense\nHusband is head both biblically and historicall… https://t.co/Op4JFvztTI', 'contenttype': 'text/plain', 'created': 0, 'id': 30, 'language': 'en'}
#
# {'content': "@mathew05538141 @charliekirk11 @Twitter @TwitterSupport Well I'm a gen-xer but okay.  I realize people like you are… https://t.co/jKJpqg2cu3", 'contenttype': 'text/plain', 'created': 0, 'id': 31, 'language': 'en'}
#
# {'content': '@blinkwluv @itzyse she suprisingly got more than yeji?? and yeji had so many lines yet was still last in screen time', 'contenttype': 'text/plain', 'created': 0, 'id': 32, 'language': 'en'}
#
# {'content': '@skinny_que My YT GF two weeks later, after I shaved her head during the night for fucking up my waves. https://t.co/ARsmtHpZO3', 'contenttype': 'text/plain', 'created': 0, 'id': 33, 'language': 'en'}
#
# {'content': 'Pick up the goat https://t.co/fXWrOnTfKK', 'contenttype': 'text/plain', 'created': 0, 'id': 34, 'language': 'en'}
#
# {'content': 'i always knew cruises were bad news', 'contenttype': 'text/plain', 'created': 0, 'id': 35, 'language': 'en'}
#
# {'content': '@EliStokols @Stonekettle If Trump dies of COVID-19 I will start going to church again.', 'contenttype': 'text/plain', 'created': 0, 'id': 36, 'language': 'en'}
#
# {'content': "U have said it out, she has😋😋😋while u don't😎😎 https://t.co/3xbVCsyn3M", 'contenttype': 'text/plain', 'created': 0, 'id': 37, 'language': 'en'}
#
# {'content': 'Claret shorts 😍 #AVFC', 'contenttype': 'text/plain', 'created': 0, 'id': 38, 'language': 'en'}
#
# {'content': 'Escaping polygamy 😯', 'contenttype': 'text/plain', 'created': 0, 'id': 39, 'language': 'en'}
#
# {'content': '@dar_ruga @EstherBirungi4 Equity not equality would make more sense\nHusband is head both biblically and historicall… https://t.co/Op4JFvztTI', 'contenttype': 'text/plain', 'created': 0, 'id': 40, 'language': 'en'}
#
# {'content': "@mathew05538141 @charliekirk11 @Twitter @TwitterSupport Well I'm a gen-xer but okay.  I realize people like you are… https://t.co/jKJpqg2cu3", 'contenttype': 'text/plain', 'created': 0, 'id': 41, 'language': 'en'}
#
# {'content': '@blinkwluv @itzyse she suprisingly got more than yeji?? and yeji had so many lines yet was still last in screen time', 'contenttype': 'text/plain', 'created': 0, 'id': 42, 'language': 'en'}
#
# {'content': '@skinny_que My YT GF two weeks later, after I shaved her head during the night for fucking up my waves. https://t.co/ARsmtHpZO3', 'contenttype': 'text/plain', 'created': 0, 'id': 43, 'language': 'en'}
#
# {'content': 'Pick up the goat https://t.co/fXWrOnTfKK', 'contenttype': 'text/plain', 'created': 0, 'id': 44, 'language': 'en'}
#
# {'content': 'i always knew cruises were bad news', 'contenttype': 'text/plain', 'created': 0, 'id': 45, 'language': 'en'}
#
# {'content': '@EliStokols @Stonekettle If Trump dies of COVID-19 I will start going to church again.', 'contenttype': 'text/plain', 'created': 0, 'id': 46, 'language': 'en'}
#
# {'content': "U have said it out, she has😋😋😋while u don't😎😎 https://t.co/3xbVCsyn3M", 'contenttype': 'text/plain', 'created': 0, 'id': 47, 'language': 'en'}
#
# {'content': 'Claret shorts 😍 #AVFC', 'contenttype': 'text/plain', 'created': 0, 'id': 48, 'language': 'en'}
#
# {'content': 'Escaping polygamy 😯', 'contenttype': 'text/plain', 'created': 0, 'id': 49, 'language': 'en'}
#
# {'content': '@dar_ruga @EstherBirungi4 Equity not equality would make more sense\nHusband is head both biblically and historicall… https://t.co/Op4JFvztTI', 'contenttype': 'text/plain', 'created': 0, 'id': 50, 'language': 'en'}
#
# {'content': "@mathew05538141 @charliekirk11 @Twitter @TwitterSupport Well I'm a gen-xer but okay.  I realize people like you are… https://t.co/jKJpqg2cu3", 'contenttype': 'text/plain', 'created': 0, 'id': 51, 'language': 'en'}
#
# {'content': '@blinkwluv @itzyse she suprisingly got more than yeji?? and yeji had so many lines yet was still last in screen time', 'contenttype': 'text/plain', 'created': 0, 'id': 52, 'language': 'en'}
#
# {'content': '@skinny_que My YT GF two weeks later, after I shaved her head during the night for fucking up my waves. https://t.co/ARsmtHpZO3', 'contenttype': 'text/plain', 'created': 0, 'id': 53, 'language': 'en'}
#
# {'content': 'Pick up the goat https://t.co/fXWrOnTfKK', 'contenttype': 'text/plain', 'created': 0, 'id': 54, 'language': 'en'}
#
# {'content': 'i always knew cruises were bad news', 'contenttype': 'text/plain', 'created': 0, 'id': 55, 'language': 'en'}
#
# {'content': '@EliStokols @Stonekettle If Trump dies of COVID-19 I will start going to church again.', 'contenttype': 'text/plain', 'created': 0, 'id': 56, 'language': 'en'}
#
# {'content': "U have said it out, she has😋😋😋while u don't😎😎 https://t.co/3xbVCsyn3M", 'contenttype': 'text/plain', 'created': 0, 'id': 57, 'language': 'en'}
#
# {'content': 'Claret shorts 😍 #AVFC', 'contenttype': 'text/plain', 'created': 0, 'id': 58, 'language': 'en'}
#
# {'content': 'Escaping polygamy 😯', 'contenttype': 'text/plain', 'created': 0, 'id': 59, 'language': 'en'}
#
# {'content': 'Whoever invented daylight savings I’m gonna shatter your knees https://t.co/DvIMzrY6tR', 'contenttype': 'text/plain', 'created': 0, 'id': 60, 'language': 'en'}
#
# {'content': '@Khan_Maximuss @VipArsenal Not really, oflate lacazetteris shitty Ozil not influential at all!', 'contenttype': 'text/plain', 'created': 0, 'id': 61, 'language': 'en'}
#
# {'content': '@LovattMo @_HelenDale @jonnnybest @allisonpearson @darrengrimes_ His defence was he was suffering from the kimonovirus', 'contenttype': 'text/plain', 'created': 0, 'id': 62, 'language': 'en'}
#
# {'content': 'Don’t I know it?!! Lol ❤️💪🏽 https://t.co/4737qHrzxI', 'contenttype': 'text/plain', 'created': 0, 'id': 63, 'language': 'en'}
#
# {'content': 'https://t.co/2ZNrlx9RsL\ndoesn’t stop them from closing the entire school district i’m in for two weeks..not one per… https://t.co/sJgqZdQBGF', 'contenttype': 'text/plain', 'created': 0, 'id': 64, 'language': 'en'}
#
# {'content': '@chyumiin I felt like i went to another dimension', 'contenttype': 'text/plain', 'created': 0, 'id': 65, 'language': 'en'}
#
# {'content': 'June 2019 - Spain Rolls Out #5G Network Using #Huawei Gear\n \nhttps://t.co/aHdGYgjpRu\n\nMarch 2020 - Spain shuts scho… https://t.co/2d6tMCHesB', 'contenttype': 'text/plain', 'created': 0, 'id': 66, 'language': 'en'}
#
# {'content': '#LOUIS: y’all dumb sorry', 'contenttype': 'text/plain', 'created': 0, 'id': 67, 'language': 'en'}
#
# {'content': '@BasTheGREAT5 Facts!!', 'contenttype': 'text/plain', 'created': 0, 'id': 68, 'language': 'en'}
#
# {'content': 'YESS YES YESS https://t.co/rvMlUNX52F', 'contenttype': 'text/plain', 'created': 0, 'id': 69, 'language': 'en'}
#
# {'content': 'Whoever invented daylight savings I’m gonna shatter your knees https://t.co/DvIMzrY6tR', 'contenttype': 'text/plain', 'created': 0, 'id': 70, 'language': 'en'}
#
# {'content': '@Khan_Maximuss @VipArsenal Not really, oflate lacazetteris shitty Ozil not influential at all!', 'contenttype': 'text/plain', 'created': 0, 'id': 71, 'language': 'en'}
#
# {'content': '@LovattMo @_HelenDale @jonnnybest @allisonpearson @darrengrimes_ His defence was he was suffering from the kimonovirus', 'contenttype': 'text/plain', 'created': 0, 'id': 72, 'language': 'en'}
#
# {'content': 'Don’t I know it?!! Lol ❤️💪🏽 https://t.co/4737qHrzxI', 'contenttype': 'text/plain', 'created': 0, 'id': 73, 'language': 'en'}
#
# {'content': 'https://t.co/2ZNrlx9RsL\ndoesn’t stop them from closing the entire school district i’m in for two weeks..not one per… https://t.co/sJgqZdQBGF', 'contenttype': 'text/plain', 'created': 0, 'id': 74, 'language': 'en'}
#
# {'content': '@chyumiin I felt like i went to another dimension', 'contenttype': 'text/plain', 'created': 0, 'id': 75, 'language': 'en'}
#
# {'content': 'June 2019 - Spain Rolls Out #5G Network Using #Huawei Gear\n \nhttps://t.co/aHdGYgjpRu\n\nMarch 2020 - Spain shuts scho… https://t.co/2d6tMCHesB', 'contenttype': 'text/plain', 'created': 0, 'id': 76, 'language': 'en'}
#
# {'content': '#LOUIS: y’all dumb sorry', 'contenttype': 'text/plain', 'created': 0, 'id': 77, 'language': 'en'}
#
# {'content': '@BasTheGREAT5 Facts!!', 'contenttype': 'text/plain', 'created': 0, 'id': 78, 'language': 'en'}
#
# {'content': 'YESS YES YESS https://t.co/rvMlUNX52F', 'contenttype': 'text/plain', 'created': 0, 'id': 79, 'language': 'en'}
#
# {'content': '@PATisDOPE 8.5 and what’s the website brody... Those pants are needed in the rotation', 'contenttype': 'text/plain', 'created': 0, 'id': 80, 'language': 'en'}
#
# {'content': '@_YorkshireRose_ I bet their spare room is currently crammed full of toilet rolls, hand gel and pasta', 'contenttype': 'text/plain', 'created': 0, 'id': 81, 'language': 'en'}
#
# {'content': '@tsn_wally @ian_mendes We wanted #Melnyk out and we’re getting #everyoneexceptMelnykout', 'contenttype': 'text/plain', 'created': 0, 'id': 82, 'language': 'en'}
#
# {'content': '@svtgaara blackpink e bts\nhttps://t.co/i1wJxKlT9I', 'contenttype': 'text/plain', 'created': 0, 'id': 83, 'language': 'en'}
#
# {'content': '@Natnai_ Serial killer activity 💀', 'contenttype': 'text/plain', 'created': 0, 'id': 84, 'language': 'en'}
#
# {'content': 'jimin popping is so powerful,sharp and hot ooof\nhttps://t.co/jqMB9eRzgv', 'contenttype': 'text/plain', 'created': 0, 'id': 85, 'language': 'en'}
#
# {'content': "@PrincessLilyMTG Have you considered adding this card to your MTG cube? It's essentially a free draw since it only… https://t.co/UAEP5TQ3do", 'contenttype': 'text/plain', 'created': 0, 'id': 86, 'language': 'en'}
#
# {'content': 'We Continue To Rebuke The Propaganda Evil False Media!\nIn Jesus’s Name!\nAmen https://t.co/yof9io4qcK', 'contenttype': 'text/plain', 'created': 0, 'id': 87, 'language': 'en'}
#
# {'content': '@leahcaitlin1234 Can’t wait 💗', 'contenttype': 'text/plain', 'created': 0, 'id': 88, 'language': 'en'}
#
# {'content': '@bmanclaus Story time?', 'contenttype': 'text/plain', 'created': 0, 'id': 89, 'language': 'en'}
#
# {'content': '@PATisDOPE 8.5 and what’s the website brody... Those pants are needed in the rotation', 'contenttype': 'text/plain', 'created': 0, 'id': 90, 'language': 'en'}
#
# {'content': '@_YorkshireRose_ I bet their spare room is currently crammed full of toilet rolls, hand gel and pasta', 'contenttype': 'text/plain', 'created': 0, 'id': 91, 'language': 'en'}
#
# {'content': '@tsn_wally @ian_mendes We wanted #Melnyk out and we’re getting #everyoneexceptMelnykout', 'contenttype': 'text/plain', 'created': 0, 'id': 92, 'language': 'en'}
#
# {'content': '@Natnai_ Serial killer activity 💀', 'contenttype': 'text/plain', 'created': 0, 'id': 93, 'language': 'en'}
#
# {'content': 'jimin popping is so powerful,sharp and hot ooof\nhttps://t.co/jqMB9eRzgv', 'contenttype': 'text/plain', 'created': 0, 'id': 94, 'language': 'en'}
#
# {'content': "@PrincessLilyMTG Have you considered adding this card to your MTG cube? It's essentially a free draw since it only… https://t.co/UAEP5TQ3do", 'contenttype': 'text/plain', 'created': 0, 'id': 95, 'language': 'en'}
#
# {'content': 'We Continue To Rebuke The Propaganda Evil False Media!\nIn Jesus’s Name!\nAmen https://t.co/yof9io4qcK', 'contenttype': 'text/plain', 'created': 0, 'id': 96, 'language': 'en'}
#
# {'content': '@leahcaitlin1234 Can’t wait 💗', 'contenttype': 'text/plain', 'created': 0, 'id': 97, 'language': 'en'}
#
# {'content': '@bmanclaus Story time?', 'contenttype': 'text/plain', 'created': 0, 'id': 98, 'language': 'en'}
#
# {'content': "@realDonaldTrump you need to be tested for COVID-19. Don't pass it to your wife and Barron.", 'contenttype': 'text/plain', 'created': 0, 'id': 99, 'language': 'en'}
#
# {'content': '@PATisDOPE 8.5 and what’s the website brody... Those pants are needed in the rotation', 'contenttype': 'text/plain', 'created': 0, 'id': 100, 'language': 'en'}
#
# {'content': '@_YorkshireRose_ I bet their spare room is currently crammed full of toilet rolls, hand gel and pasta', 'contenttype': 'text/plain', 'created': 0, 'id': 101, 'language': 'en'}
#
# {'content': '@tsn_wally @ian_mendes We wanted #Melnyk out and we’re getting #everyoneexceptMelnykout', 'contenttype': 'text/plain', 'created': 0, 'id': 102, 'language': 'en'}
#
# {'content': '@Natnai_ Serial killer activity 💀', 'contenttype': 'text/plain', 'created': 0, 'id': 103, 'language': 'en'}
#
# {'content': 'jimin popping is so powerful,sharp and hot ooof\nhttps://t.co/jqMB9eRzgv', 'contenttype': 'text/plain', 'created': 0, 'id': 104, 'language': 'en'}
#
# {'content': "@PrincessLilyMTG Have you considered adding this card to your MTG cube? It's essentially a free draw since it only… https://t.co/UAEP5TQ3do", 'contenttype': 'text/plain', 'created': 0, 'id': 105, 'language': 'en'}
#
# {'content': 'We Continue To Rebuke The Propaganda Evil False Media!\nIn Jesus’s Name!\nAmen https://t.co/yof9io4qcK', 'contenttype': 'text/plain', 'created': 0, 'id': 106, 'language': 'en'}
#
# {'content': '@leahcaitlin1234 Can’t wait 💗', 'contenttype': 'text/plain', 'created': 0, 'id': 107, 'language': 'en'}
#
# {'content': '@bmanclaus Story time?', 'contenttype': 'text/plain', 'created': 0, 'id': 108, 'language': 'en'}
#
# {'content': "@realDonaldTrump you need to be tested for COVID-19. Don't pass it to your wife and Barron.", 'contenttype': 'text/plain', 'created': 0, 'id': 109, 'language': 'en'}
#
# {'content': '@NuthinOnBartee I’ll be there end end of April tho. Flight was booked yesterday.', 'contenttype': 'text/plain', 'created': 0, 'id': 110, 'language': 'en'}
#
# {'content': "@Breaking911 I'm shocked the gas mask didn't work! 😂", 'contenttype': 'text/plain', 'created': 0, 'id': 111, 'language': 'en'}
#
# {'content': '@PatPenn2 @FLAGDEFENDER1 Soros is the anrichrist', 'contenttype': 'text/plain', 'created': 0, 'id': 112, 'language': 'en'}
#
# {'content': '@ObeseGiraffeYT Is this legit? What’s the method?', 'contenttype': 'text/plain', 'created': 0, 'id': 113, 'language': 'en'}
#
# {'content': 'dang is EVERYONE in Punta Cana rn \U0001f97a', 'contenttype': 'text/plain', 'created': 0, 'id': 114, 'language': 'en'}
#
# {'content': '@Meche____ @Bujutoyourears Afro fusion legend🙌', 'contenttype': 'text/plain', 'created': 0, 'id': 115, 'language': 'en'}
#
# {'content': '@sojapojke Needle holder?', 'contenttype': 'text/plain', 'created': 0, 'id': 116, 'language': 'en'}
#
# {'content': 'i am trans ..... lucent .', 'contenttype': 'text/plain', 'created': 0, 'id': 117, 'language': 'en'}
#
# {'content': '@xoxobitchzz Its only the truth, theres no need', 'contenttype': 'text/plain', 'created': 0, 'id': 118, 'language': 'en'}
#
# {'content': "Hadn't seen it for myself until this morning, quite sad when you go to supermarket to get some bread and milk as it… https://t.co/CtrVmeO5V4", 'contenttype': 'text/plain', 'created': 0, 'id': 119, 'language': 'en'}
#
# {'content': '@NuthinOnBartee I’ll be there end end of April tho. Flight was booked yesterday.', 'contenttype': 'text/plain', 'created': 0, 'id': 120, 'language': 'en'}
#
# {'content': "@Breaking911 I'm shocked the gas mask didn't work! 😂", 'contenttype': 'text/plain', 'created': 0, 'id': 121, 'language': 'en'}
#
# {'content': '@PatPenn2 @FLAGDEFENDER1 Soros is the anrichrist', 'contenttype': 'text/plain', 'created': 0, 'id': 122, 'language': 'en'}
#
# {'content': '@ObeseGiraffeYT Is this legit? What’s the method?', 'contenttype': 'text/plain', 'created': 0, 'id': 123, 'language': 'en'}
#
# {'content': 'dang is EVERYONE in Punta Cana rn \U0001f97a', 'contenttype': 'text/plain', 'created': 0, 'id': 124, 'language': 'en'}
#
# {'content': '@Meche____ @Bujutoyourears Afro fusion legend🙌', 'contenttype': 'text/plain', 'created': 0, 'id': 125, 'language': 'en'}
#
# {'content': '@sojapojke Needle holder?', 'contenttype': 'text/plain', 'created': 0, 'id': 126, 'language': 'en'}
#
# {'content': 'i am trans ..... lucent .', 'contenttype': 'text/plain', 'created': 0, 'id': 127, 'language': 'en'}
#
# {'content': '@xoxobitchzz Its only the truth, theres no need', 'contenttype': 'text/plain', 'created': 0, 'id': 128, 'language': 'en'}
#
# {'content': "Hadn't seen it for myself until this morning, quite sad when you go to supermarket to get some bread and milk as it… https://t.co/CtrVmeO5V4", 'contenttype': 'text/plain', 'created': 0, 'id': 129, 'language': 'en'}
#
# {'content': '@NuthinOnBartee I’ll be there end end of April tho. Flight was booked yesterday.', 'contenttype': 'text/plain', 'created': 0, 'id': 130, 'language': 'en'}
#
# {'content': "@Breaking911 I'm shocked the gas mask didn't work! 😂", 'contenttype': 'text/plain', 'created': 0, 'id': 131, 'language': 'en'}
#
# {'content': '@PatPenn2 @FLAGDEFENDER1 Soros is the anrichrist', 'contenttype': 'text/plain', 'created': 0, 'id': 132, 'language': 'en'}
#
# {'content': '@ObeseGiraffeYT Is this legit? What’s the method?', 'contenttype': 'text/plain', 'created': 0, 'id': 133, 'language': 'en'}
#
# {'content': 'dang is EVERYONE in Punta Cana rn \U0001f97a', 'contenttype': 'text/plain', 'created': 0, 'id': 134, 'language': 'en'}
#
# {'content': '@Meche____ @Bujutoyourears Afro fusion legend🙌', 'contenttype': 'text/plain', 'created': 0, 'id': 135, 'language': 'en'}
#
# {'content': '@sojapojke Needle holder?', 'contenttype': 'text/plain', 'created': 0, 'id': 136, 'language': 'en'}
#
# {'content': 'i am trans ..... lucent .', 'contenttype': 'text/plain', 'created': 0, 'id': 137, 'language': 'en'}
#
# {'content': '@xoxobitchzz Its only the truth, theres no need', 'contenttype': 'text/plain', 'created': 0, 'id': 138, 'language': 'en'}
#
# {'content': "Hadn't seen it for myself until this morning, quite sad when you go to supermarket to get some bread and milk as it… https://t.co/CtrVmeO5V4", 'contenttype': 'text/plain', 'created': 0, 'id': 139, 'language': 'en'}
#
# {'content': 'What if I have a matron AND a maid of honor', 'contenttype': 'text/plain', 'created': 0, 'id': 140, 'language': 'en'}
#
# {'content': '@Themba93132630 Eish bro you will be rich yhooo https://t.co/U9jqIXmy8Z', 'contenttype': 'text/plain', 'created': 0, 'id': 141, 'language': 'en'}
#
# {'content': '@KindestLotus A lot? •u•)', 'contenttype': 'text/plain', 'created': 0, 'id': 142, 'language': 'en'}
#
# {'content': '@CurtisGCracker 👀 I wanna do this too! \nAs for the horns, I wanna see double horns, kinda like a crown?', 'contenttype': 'text/plain', 'created': 0, 'id': 143, 'language': 'en'}
#
# {'content': 'Quick, simple to prepare and packed full of delicious Mexican flavours, these Easy Beef Enchiladas are the perfect… https://t.co/Tfxwlts9Ei', 'contenttype': 'text/plain', 'created': 0, 'id': 144, 'language': 'en'}
#
# {'content': 'My 4 year old and I were at the store and pointing to the cologne in the glass cabinet she asked me what it was, I… https://t.co/NyAreomOQ1', 'contenttype': 'text/plain', 'created': 0, 'id': 145, 'language': 'en'}
#
# {'content': '@Angellight4u Congratulations!', 'contenttype': 'text/plain', 'created': 0, 'id': 146, 'language': 'en'}
#
# {'content': "@bayesianboy Yes. See Marcel Quarfood's dissertation or book. Think I got the spelling right. Or other refs to him.", 'contenttype': 'text/plain', 'created': 0, 'id': 147, 'language': 'en'}
#
# {'content': "@KatherineWyvern Yes if I were a young maiden gone down to bathe in the forest pool and I saw him, I'd be very afra… https://t.co/IBmbpy2Y8v", 'contenttype': 'text/plain', 'created': 0, 'id': 148, 'language': 'en'}
#
# {'content': '@realDonaldTrump This is not a fire &amp; forget crisis mate. Don’t pat yourself on the back for 1 early decision that… https://t.co/YuJSO07Q9X', 'contenttype': 'text/plain', 'created': 0, 'id': 149, 'language': 'en'}
#
# {'content': 'Food always puts me in a good mood', 'contenttype': 'text/plain', 'created': 0, 'id': 150, 'language': 'en'}
#
# {'content': "@donachaidh She's hot tho", 'contenttype': 'text/plain', 'created': 0, 'id': 151, 'language': 'en'}
#
# {'content': '@P0A_Triot23 11:39 am EDT, 03/09/2020\nW H R A C 4D ...\n\nH A C D A W I T .\n5D H W C .\nA (TOGETHER) N .', 'contenttype': 'text/plain', 'created': 0, 'id': 152, 'language': 'en'}
#
# {'content': '$SNCR NEW ARTICLE : Synchronoss reports mixed Q4 results https://t.co/QMRllX5z1n Get all the latest $SNCR related n… https://t.co/bmxyuZzby7', 'contenttype': 'text/plain', 'created': 0, 'id': 153, 'language': 'en'}
#
# {'content': '@bersuozr @fattyyyma Shouq wallah same😳😳😳', 'contenttype': 'text/plain', 'created': 0, 'id': 154, 'language': 'en'}
#
# {'content': 'holy shit cumali is right behind cagatay #içerde', 'contenttype': 'text/plain', 'created': 0, 'id': 155, 'language': 'en'}
#
# {'content': 'DAN RIGHTS https://t.co/nVmcMNkAj2', 'contenttype': 'text/plain', 'created': 0, 'id': 156, 'language': 'en'}
#
# {'content': 'Go lakers nice back to back wins...35 years old? You don’t say', 'contenttype': 'text/plain', 'created': 0, 'id': 157, 'language': 'en'}
#
# {'content': '@area51elvis @Queeni_Martini @prayingmedic Just when it goes up, it is Obama\'s "good work"???? lol', 'contenttype': 'text/plain', 'created': 0, 'id': 158, 'language': 'en'}
#
# {'content': 'Part-time Brand Ambassador positions are available in the following locations: \u2063\nIllinois - Lake/McHenry/Kane Count… https://t.co/TS7qb5L43I', 'contenttype': 'text/plain', 'created': 0, 'id': 159, 'language': 'en'}
#
# {'content': 'Food always puts me in a good mood', 'contenttype': 'text/plain', 'created': 0, 'id': 160, 'language': 'en'}
#
# {'content': "@donachaidh She's hot tho", 'contenttype': 'text/plain', 'created': 0, 'id': 161, 'language': 'en'}
#
# {'content': '@P0A_Triot23 11:39 am EDT, 03/09/2020\nW H R A C 4D ...\n\nH A C D A W I T .\n5D H W C .\nA (TOGETHER) N .', 'contenttype': 'text/plain', 'created': 0, 'id': 162, 'language': 'en'}
#
# {'content': '$SNCR NEW ARTICLE : Synchronoss reports mixed Q4 results https://t.co/QMRllX5z1n Get all the latest $SNCR related n… https://t.co/bmxyuZzby7', 'contenttype': 'text/plain', 'created': 0, 'id': 163, 'language': 'en'}
#
# {'content': '@bersuozr @fattyyyma Shouq wallah same😳😳😳', 'contenttype': 'text/plain', 'created': 0, 'id': 164, 'language': 'en'}
#
# {'content': 'holy shit cumali is right behind cagatay #içerde', 'contenttype': 'text/plain', 'created': 0, 'id': 165, 'language': 'en'}
#
# {'content': 'DAN RIGHTS https://t.co/nVmcMNkAj2', 'contenttype': 'text/plain', 'created': 0, 'id': 166, 'language': 'en'}
#
# {'content': 'Go lakers nice back to back wins...35 years old? You don’t say', 'contenttype': 'text/plain', 'created': 0, 'id': 167, 'language': 'en'}
#
# {'content': '@area51elvis @Queeni_Martini @prayingmedic Just when it goes up, it is Obama\'s "good work"???? lol', 'contenttype': 'text/plain', 'created': 0, 'id': 168, 'language': 'en'}
#
# {'content': 'Part-time Brand Ambassador positions are available in the following locations: \u2063\nIllinois - Lake/McHenry/Kane Count… https://t.co/TS7qb5L43I', 'contenttype': 'text/plain', 'created': 0, 'id': 169, 'language': 'en'}
#
# {'content': 'Food always puts me in a good mood', 'contenttype': 'text/plain', 'created': 0, 'id': 170, 'language': 'en'}
#
# {'content': "@donachaidh She's hot tho", 'contenttype': 'text/plain', 'created': 0, 'id': 171, 'language': 'en'}
#
# {'content': '@P0A_Triot23 11:39 am EDT, 03/09/2020\nW H R A C 4D ...\n\nH A C D A W I T .\n5D H W C .\nA (TOGETHER) N .', 'contenttype': 'text/plain', 'created': 0, 'id': 172, 'language': 'en'}
#
# {'content': '$SNCR NEW ARTICLE : Synchronoss reports mixed Q4 results https://t.co/QMRllX5z1n Get all the latest $SNCR related n… https://t.co/bmxyuZzby7', 'contenttype': 'text/plain', 'created': 0, 'id': 173, 'language': 'en'}
#
# {'content': '@bersuozr @fattyyyma Shouq wallah same😳😳😳', 'contenttype': 'text/plain', 'created': 0, 'id': 174, 'language': 'en'}
#
# {'content': 'holy shit cumali is right behind cagatay #içerde', 'contenttype': 'text/plain', 'created': 0, 'id': 175, 'language': 'en'}
#
# {'content': 'DAN RIGHTS https://t.co/nVmcMNkAj2', 'contenttype': 'text/plain', 'created': 0, 'id': 176, 'language': 'en'}
#
# {'content': 'Go lakers nice back to back wins...35 years old? You don’t say', 'contenttype': 'text/plain', 'created': 0, 'id': 177, 'language': 'en'}
#
# {'content': '@area51elvis @Queeni_Martini @prayingmedic Just when it goes up, it is Obama\'s "good work"???? lol', 'contenttype': 'text/plain', 'created': 0, 'id': 178, 'language': 'en'}
#
# {'content': 'Part-time Brand Ambassador positions are available in the following locations: \u2063\nIllinois - Lake/McHenry/Kane Count… https://t.co/TS7qb5L43I', 'contenttype': 'text/plain', 'created': 0, 'id': 179, 'language': 'en'}
#
# {'content': 'also i could appreciate getting crystals too.. need spark funds onegai shimaku', 'contenttype': 'text/plain', 'created': 0, 'id': 180, 'language': 'en'}
#
# {'content': '@Kamto_U @Etin_joe I can see you stressed out and you keep calling', 'contenttype': 'text/plain', 'created': 0, 'id': 181, 'language': 'en'}
#
# {'content': 'Good thing that Jungkook is wearing his baseball cap, and Yanna was too frightened to look at her savior so JK took… https://t.co/znWJjTnAGK', 'contenttype': 'text/plain', 'created': 0, 'id': 182, 'language': 'en'}
#
# {'content': "you know i'm ur type RIGHT?", 'contenttype': 'text/plain', 'created': 0, 'id': 183, 'language': 'en'}
#
# {'content': '@david_tzatziki I gasped', 'contenttype': 'text/plain', 'created': 0, 'id': 184, 'language': 'en'}
#
# {'content': "@deepadoc @IshitaYadav That's getting worst now", 'contenttype': 'text/plain', 'created': 0, 'id': 185, 'language': 'en'}
#
# {'content': '@Lizkthequeen @EstherBirungi4 I’m fine dear. You? \nHaza ndimu mpora mpora', 'contenttype': 'text/plain', 'created': 0, 'id': 186, 'language': 'en'}
#
# {'content': '@YG_Drag @VIZMedia @HxHSource I THOUGHT I WAS THE ONLY ONE', 'contenttype': 'text/plain', 'created': 0, 'id': 187, 'language': 'en'}
#
# {'content': 'See my gf and spoil the homies https://t.co/KjcNLHrKTq', 'contenttype': 'text/plain', 'created': 0, 'id': 188, 'language': 'en'}
#
# {'content': '@HakuPamfer Man that’s awful :(', 'contenttype': 'text/plain', 'created': 0, 'id': 189, 'language': 'en'}
#
# {'content': 'also i could appreciate getting crystals too.. need spark funds onegai shimaku', 'contenttype': 'text/plain', 'created': 0, 'id': 190, 'language': 'en'}
#
# {'content': '@Kamto_U @Etin_joe I can see you stressed out and you keep calling', 'contenttype': 'text/plain', 'created': 0, 'id': 191, 'language': 'en'}
#
# {'content': 'Good thing that Jungkook is wearing his baseball cap, and Yanna was too frightened to look at her savior so JK took… https://t.co/znWJjTnAGK', 'contenttype': 'text/plain', 'created': 0, 'id': 192, 'language': 'en'}
#
# {'content': "you know i'm ur type RIGHT?", 'contenttype': 'text/plain', 'created': 0, 'id': 193, 'language': 'en'}
#
# {'content': '@david_tzatziki I gasped', 'contenttype': 'text/plain', 'created': 0, 'id': 194, 'language': 'en'}
#
# {'content': "@deepadoc @IshitaYadav That's getting worst now", 'contenttype': 'text/plain', 'created': 0, 'id': 195, 'language': 'en'}
#
# {'content': '@Lizkthequeen @EstherBirungi4 I’m fine dear. You? \nHaza ndimu mpora mpora', 'contenttype': 'text/plain', 'created': 0, 'id': 196, 'language': 'en'}
#
# {'content': '@YG_Drag @VIZMedia @HxHSource I THOUGHT I WAS THE ONLY ONE', 'contenttype': 'text/plain', 'created': 0, 'id': 197, 'language': 'en'}
#
# {'content': 'See my gf and spoil the homies https://t.co/KjcNLHrKTq', 'contenttype': 'text/plain', 'created': 0, 'id': 198, 'language': 'en'}
#
# {'content': '@HakuPamfer Man that’s awful :(', 'contenttype': 'text/plain', 'created': 0, 'id': 199, 'language': 'en'}
#
# {'content': 'also i could appreciate getting crystals too.. need spark funds onegai shimaku', 'contenttype': 'text/plain', 'created': 0, 'id': 200, 'language': 'en'}
#
# {'content': '@Kamto_U @Etin_joe I can see you stressed out and you keep calling', 'contenttype': 'text/plain', 'created': 0, 'id': 201, 'language': 'en'}
#
# {'content': 'Good thing that Jungkook is wearing his baseball cap, and Yanna was too frightened to look at her savior so JK took… https://t.co/znWJjTnAGK', 'contenttype': 'text/plain', 'created': 0, 'id': 202, 'language': 'en'}
#
# {'content': "you know i'm ur type RIGHT?", 'contenttype': 'text/plain', 'created': 0, 'id': 203, 'language': 'en'}
#
# {'content': '@david_tzatziki I gasped', 'contenttype': 'text/plain', 'created': 0, 'id': 204, 'language': 'en'}
#
# {'content': "@deepadoc @IshitaYadav That's getting worst now", 'contenttype': 'text/plain', 'created': 0, 'id': 205, 'language': 'en'}
#
# {'content': '@Lizkthequeen @EstherBirungi4 I’m fine dear. You? \nHaza ndimu mpora mpora', 'contenttype': 'text/plain', 'created': 0, 'id': 206, 'language': 'en'}
#
# {'content': '@YG_Drag @VIZMedia @HxHSource I THOUGHT I WAS THE ONLY ONE', 'contenttype': 'text/plain', 'created': 0, 'id': 207, 'language': 'en'}
#
# {'content': 'See my gf and spoil the homies https://t.co/KjcNLHrKTq', 'contenttype': 'text/plain', 'created': 0, 'id': 208, 'language': 'en'}
#
# {'content': '@HakuPamfer Man that’s awful :(', 'contenttype': 'text/plain', 'created': 0, 'id': 209, 'language': 'en'}
#
# {'content': '@Mechagaikotsu @Thesixth_pulsar @Grimlock4pres The HG of it is good though', 'contenttype': 'text/plain', 'created': 0, 'id': 210, 'language': 'en'}
#
# {'content': '@queendayj I Miss You Too❤️😘 &amp; Headed To Get A Pedicure', 'contenttype': 'text/plain', 'created': 0, 'id': 211, 'language': 'en'}
#
# {'content': 'Dude said Da Baby’s verse bout to slap 💀💀 https://t.co/1omnCdGYDq', 'contenttype': 'text/plain', 'created': 0, 'id': 212, 'language': 'en'}
#
# {'content': '@GovMikeHuckabee @realDonaldTrump What an evil sick human. Black heart', 'contenttype': 'text/plain', 'created': 0, 'id': 213, 'language': 'en'}
#
# {'content': 'Weed a clock', 'contenttype': 'text/plain', 'created': 0, 'id': 214, 'language': 'en'}
#
# {'content': '@_jwilliams_____ Be safe bro', 'contenttype': 'text/plain', 'created': 0, 'id': 215, 'language': 'en'}
#
# {'content': '@kommandostore Perfect! For those warzone medical applications where it’s death or ‘attach directly into your Femur’', 'contenttype': 'text/plain', 'created': 0, 'id': 216, 'language': 'en'}
#
# {'content': "@Foxy_Cosplay I love her. She's everything ive ever wanted to be. Kind, but doesn't let people walk on her.", 'contenttype': 'text/plain', 'created': 0, 'id': 217, 'language': 'en'}
#
# {'content': 'I don’t care what y’all say I’m about to catch one of these cheap flights somewhere 👀\U0001f974😂 https://t.co/QLTuFg0S6Y', 'contenttype': 'text/plain', 'created': 0, 'id': 218, 'language': 'en'}
#
# {'content': 'Love you my Hero @DanAuito 💯💯☘️ https://t.co/ljaW9PQqeY', 'contenttype': 'text/plain', 'created': 0, 'id': 219, 'language': 'en'}
#
# {'content': '@Mechagaikotsu @Thesixth_pulsar @Grimlock4pres The HG of it is good though', 'contenttype': 'text/plain', 'created': 0, 'id': 220, 'language': 'en'}
#
# {'content': '@queendayj I Miss You Too❤️😘 &amp; Headed To Get A Pedicure', 'contenttype': 'text/plain', 'created': 0, 'id': 221, 'language': 'en'}
#
# {'content': 'Dude said Da Baby’s verse bout to slap 💀💀 https://t.co/1omnCdGYDq', 'contenttype': 'text/plain', 'created': 0, 'id': 222, 'language': 'en'}
#
# {'content': '@GovMikeHuckabee @realDonaldTrump What an evil sick human. Black heart', 'contenttype': 'text/plain', 'created': 0, 'id': 223, 'language': 'en'}
#
# {'content': 'Weed a clock', 'contenttype': 'text/plain', 'created': 0, 'id': 224, 'language': 'en'}
#
# {'content': '@_jwilliams_____ Be safe bro', 'contenttype': 'text/plain', 'created': 0, 'id': 225, 'language': 'en'}
#
# {'content': '@kommandostore Perfect! For those warzone medical applications where it’s death or ‘attach directly into your Femur’', 'contenttype': 'text/plain', 'created': 0, 'id': 226, 'language': 'en'}
#
# {'content': "@Foxy_Cosplay I love her. She's everything ive ever wanted to be. Kind, but doesn't let people walk on her.", 'contenttype': 'text/plain', 'created': 0, 'id': 227, 'language': 'en'}
#
# {'content': 'I don’t care what y’all say I’m about to catch one of these cheap flights somewhere 👀\U0001f974😂 https://t.co/QLTuFg0S6Y', 'contenttype': 'text/plain', 'created': 0, 'id': 228, 'language': 'en'}
#
# {'content': 'Love you my Hero @DanAuito 💯💯☘️ https://t.co/ljaW9PQqeY', 'contenttype': 'text/plain', 'created': 0, 'id': 229, 'language': 'en'}
#
# {'content': '@Mechagaikotsu @Thesixth_pulsar @Grimlock4pres The HG of it is good though', 'contenttype': 'text/plain', 'created': 0, 'id': 230, 'language': 'en'}
#
# {'content': '@queendayj I Miss You Too❤️😘 &amp; Headed To Get A Pedicure', 'contenttype': 'text/plain', 'created': 0, 'id': 231, 'language': 'en'}
#
# {'content': 'Dude said Da Baby’s verse bout to slap 💀💀 https://t.co/1omnCdGYDq', 'contenttype': 'text/plain', 'created': 0, 'id': 232, 'language': 'en'}
#
# {'content': '@GovMikeHuckabee @realDonaldTrump What an evil sick human. Black heart', 'contenttype': 'text/plain', 'created': 0, 'id': 233, 'language': 'en'}
#
# {'content': 'Weed a clock', 'contenttype': 'text/plain', 'created': 0, 'id': 234, 'language': 'en'}
#
# {'content': '@_jwilliams_____ Be safe bro', 'contenttype': 'text/plain', 'created': 0, 'id': 235, 'language': 'en'}
#
# {'content': '@kommandostore Perfect! For those warzone medical applications where it’s death or ‘attach directly into your Femur’', 'contenttype': 'text/plain', 'created': 0, 'id': 236, 'language': 'en'}
#
# {'content': "@Foxy_Cosplay I love her. She's everything ive ever wanted to be. Kind, but doesn't let people walk on her.", 'contenttype': 'text/plain', 'created': 0, 'id': 237, 'language': 'en'}
#
# {'content': 'I don’t care what y’all say I’m about to catch one of these cheap flights somewhere 👀\U0001f974😂 https://t.co/QLTuFg0S6Y', 'contenttype': 'text/plain', 'created': 0, 'id': 238, 'language': 'en'}
#
# {'content': 'Love you my Hero @DanAuito 💯💯☘️ https://t.co/ljaW9PQqeY', 'contenttype': 'text/plain', 'created': 0, 'id': 239, 'language': 'en'}
#
# {'content': '@athalarsbryce Not telling you how to live your life, but do it', 'contenttype': 'text/plain', 'created': 0, 'id': 240, 'language': 'en'}
#
# {'content': "@yxiao1988 Yeah, that's true.", 'contenttype': 'text/plain', 'created': 0, 'id': 241, 'language': 'en'}
#
# {'content': 'do y’all know realize how shit like this sounds like https://t.co/MBRB4di1eL', 'contenttype': 'text/plain', 'created': 0, 'id': 242, 'language': 'en'}
#
# {'content': '@Kytrex ur not funny', 'contenttype': 'text/plain', 'created': 0, 'id': 243, 'language': 'en'}
#
# {'content': 'Either way you getting shot at😂 https://t.co/KTXDGh7HdN', 'contenttype': 'text/plain', 'created': 0, 'id': 244, 'language': 'en'}
#
# {'content': 'Happy Birthday pretty pretty girl 🤤\U0001f970❤️ https://t.co/kr1mZIzBiQ', 'contenttype': 'text/plain', 'created': 0, 'id': 245, 'language': 'en'}
#
# {'content': '@auth_ntic @OfficialAggro YESSIRRRRRRRRRRRRRR ily', 'contenttype': 'text/plain', 'created': 0, 'id': 246, 'language': 'en'}
#
# {'content': 'Babey 💙💙💙💙💙💙💙💙💙💙\n\ni ordered Commission page doll from https://t.co/U7AqNzzRBi and i really really love this so much… https://t.co/5jQ7ppc42q', 'contenttype': 'text/plain', 'created': 0, 'id': 247, 'language': 'en'}
#
# {'content': 'Strawberry kee you dia😏 https://t.co/VmdhPm0nd2', 'contenttype': 'text/plain', 'created': 0, 'id': 248, 'language': 'en'}
#
# {'content': '@cjafterdark You dare diss Ellen DeGeneres\n\nShe was a fish once', 'contenttype': 'text/plain', 'created': 0, 'id': 249, 'language': 'en'}
#
# {'content': '@athalarsbryce Not telling you how to live your life, but do it', 'contenttype': 'text/plain', 'created': 0, 'id': 250, 'language': 'en'}
#
# {'content': "@yxiao1988 Yeah, that's true.", 'contenttype': 'text/plain', 'created': 0, 'id': 251, 'language': 'en'}
#
# {'content': 'do y’all know realize how shit like this sounds like https://t.co/MBRB4di1eL', 'contenttype': 'text/plain', 'created': 0, 'id': 252, 'language': 'en'}
#
# {'content': '@Kytrex ur not funny', 'contenttype': 'text/plain', 'created': 0, 'id': 253, 'language': 'en'}
#
# {'content': 'Either way you getting shot at😂 https://t.co/KTXDGh7HdN', 'contenttype': 'text/plain', 'created': 0, 'id': 254, 'language': 'en'}
#
# {'content': 'Happy Birthday pretty pretty girl 🤤\U0001f970❤️ https://t.co/kr1mZIzBiQ', 'contenttype': 'text/plain', 'created': 0, 'id': 255, 'language': 'en'}
#
# {'content': '@auth_ntic @OfficialAggro YESSIRRRRRRRRRRRRRR ily', 'contenttype': 'text/plain', 'created': 0, 'id': 256, 'language': 'en'}
#
# {'content': 'Babey 💙💙💙💙💙💙💙💙💙💙\n\ni ordered Commission page doll from https://t.co/U7AqNzzRBi and i really really love this so much… https://t.co/5jQ7ppc42q', 'contenttype': 'text/plain', 'created': 0, 'id': 257, 'language': 'en'}
#
# {'content': 'Strawberry kee you dia😏 https://t.co/VmdhPm0nd2', 'contenttype': 'text/plain', 'created': 0, 'id': 258, 'language': 'en'}
#
# {'content': '@cjafterdark You dare diss Ellen DeGeneres\n\nShe was a fish once', 'contenttype': 'text/plain', 'created': 0, 'id': 259, 'language': 'en'}
#
# {'content': '@athalarsbryce Not telling you how to live your life, but do it', 'contenttype': 'text/plain', 'created': 0, 'id': 260, 'language': 'en'}
#
# {'content': "@yxiao1988 Yeah, that's true.", 'contenttype': 'text/plain', 'created': 0, 'id': 261, 'language': 'en'}
#
# {'content': 'do y’all know realize how shit like this sounds like https://t.co/MBRB4di1eL', 'contenttype': 'text/plain', 'created': 0, 'id': 262, 'language': 'en'}
#
# {'content': '@Kytrex ur not funny', 'contenttype': 'text/plain', 'created': 0, 'id': 263, 'language': 'en'}
#
# {'content': 'Either way you getting shot at😂 https://t.co/KTXDGh7HdN', 'contenttype': 'text/plain', 'created': 0, 'id': 264, 'language': 'en'}
#
# {'content': 'Happy Birthday pretty pretty girl 🤤\U0001f970❤️ https://t.co/kr1mZIzBiQ', 'contenttype': 'text/plain', 'created': 0, 'id': 265, 'language': 'en'}
#
# {'content': '@auth_ntic @OfficialAggro YESSIRRRRRRRRRRRRRR ily', 'contenttype': 'text/plain', 'created': 0, 'id': 266, 'language': 'en'}
#
# {'content': 'Babey 💙💙💙💙💙💙💙💙💙💙\n\ni ordered Commission page doll from https://t.co/U7AqNzzRBi and i really really love this so much… https://t.co/5jQ7ppc42q', 'contenttype': 'text/plain', 'created': 0, 'id': 267, 'language': 'en'}
#
# {'content': 'Strawberry kee you dia😏 https://t.co/VmdhPm0nd2', 'contenttype': 'text/plain', 'created': 0, 'id': 268, 'language': 'en'}
#
# {'content': '@cjafterdark You dare diss Ellen DeGeneres\n\nShe was a fish once', 'contenttype': 'text/plain', 'created': 0, 'id': 269, 'language': 'en'}
#
# {'content': '@sage_wmn The latter part of this thread!Trump for President in Russia 2020', 'contenttype': 'text/plain', 'created': 0, 'id': 270, 'language': 'en'}
#
# {'content': '@PaxtonRoadUpper But anyone worried can get on the magic bus , that’s the last one I promise!', 'contenttype': 'text/plain', 'created': 0, 'id': 271, 'language': 'en'}
#
# {'content': '@speedwaffle I had the same on my 98/99 shirt but someone pinched it. \U0001f92c\U0001f92c', 'contenttype': 'text/plain', 'created': 0, 'id': 272, 'language': 'en'}
#
# {'content': 'I have the tendency to judge people based on their facial expressions and their body language.', 'contenttype': 'text/plain', 'created': 0, 'id': 273, 'language': 'en'}
#
# {'content': "I just earned the 'Land of the Free  (Level 40)' badge on @untappd! https://t.co/pb6jdlOK2J", 'contenttype': 'text/plain', 'created': 0, 'id': 274, 'language': 'en'}
#
# {'content': '@SlumpBuster1978 @GunnelsWarren Ok yeah the politicians they own forced them to take it.', 'contenttype': 'text/plain', 'created': 0, 'id': 275, 'language': 'en'}
#
# {'content': '@TMZ Why do they hate each other? Aren’t they both LA teams?', 'contenttype': 'text/plain', 'created': 0, 'id': 276, 'language': 'en'}
#
# {'content': '@AWorldOutOfMind @PianistRichard Agree, fuck religion.', 'contenttype': 'text/plain', 'created': 0, 'id': 277, 'language': 'en'}
#
# {'content': '@Thola_md Goodnight ❤❤.', 'contenttype': 'text/plain', 'created': 0, 'id': 278, 'language': 'en'}
#
# {'content': '@realDonaldTrump 😁👍Absolutely!', 'contenttype': 'text/plain', 'created': 0, 'id': 279, 'language': 'en'}
#
# {'content': '@sage_wmn The latter part of this thread!Trump for President in Russia 2020', 'contenttype': 'text/plain', 'created': 0, 'id': 280, 'language': 'en'}
#
# {'content': '@PaxtonRoadUpper But anyone worried can get on the magic bus , that’s the last one I promise!', 'contenttype': 'text/plain', 'created': 0, 'id': 281, 'language': 'en'}
#
# {'content': '@speedwaffle I had the same on my 98/99 shirt but someone pinched it. \U0001f92c\U0001f92c', 'contenttype': 'text/plain', 'created': 0, 'id': 282, 'language': 'en'}
#
# {'content': 'I have the tendency to judge people based on their facial expressions and their body language.', 'contenttype': 'text/plain', 'created': 0, 'id': 283, 'language': 'en'}
#
# {'content': '@SlumpBuster1978 @GunnelsWarren Ok yeah the politicians they own forced them to take it.', 'contenttype': 'text/plain', 'created': 0, 'id': 284, 'language': 'en'}
#
# {'content': '@TMZ Why do they hate each other? Aren’t they both LA teams?', 'contenttype': 'text/plain', 'created': 0, 'id': 285, 'language': 'en'}
#
# {'content': '@AWorldOutOfMind @PianistRichard Agree, fuck religion.', 'contenttype': 'text/plain', 'created': 0, 'id': 286, 'language': 'en'}
#
# {'content': '@Thola_md Goodnight ❤❤.', 'contenttype': 'text/plain', 'created': 0, 'id': 287, 'language': 'en'}
#
# {'content': '@realDonaldTrump 😁👍Absolutely!', 'contenttype': 'text/plain', 'created': 0, 'id': 288, 'language': 'en'}
#
# {'content': '@jilliann_reese love &amp; miss bean 💞', 'contenttype': 'text/plain', 'created': 0, 'id': 289, 'language': 'en'}
#
# {'content': '@sage_wmn The latter part of this thread!Trump for President in Russia 2020', 'contenttype': 'text/plain', 'created': 0, 'id': 290, 'language': 'en'}
#
# {'content': '@PaxtonRoadUpper But anyone worried can get on the magic bus , that’s the last one I promise!', 'contenttype': 'text/plain', 'created': 0, 'id': 291, 'language': 'en'}
#
# {'content': '@speedwaffle I had the same on my 98/99 shirt but someone pinched it. \U0001f92c\U0001f92c', 'contenttype': 'text/plain', 'created': 0, 'id': 292, 'language': 'en'}
#
# {'content': 'I have the tendency to judge people based on their facial expressions and their body language.', 'contenttype': 'text/plain', 'created': 0, 'id': 293, 'language': 'en'}
#
# {'content': '@SlumpBuster1978 @GunnelsWarren Ok yeah the politicians they own forced them to take it.', 'contenttype': 'text/plain', 'created': 0, 'id': 294, 'language': 'en'}
#
# {'content': '@TMZ Why do they hate each other? Aren’t they both LA teams?', 'contenttype': 'text/plain', 'created': 0, 'id': 295, 'language': 'en'}
#
# {'content': '@AWorldOutOfMind @PianistRichard Agree, fuck religion.', 'contenttype': 'text/plain', 'created': 0, 'id': 296, 'language': 'en'}
#
# {'content': '@Thola_md Goodnight ❤❤.', 'contenttype': 'text/plain', 'created': 0, 'id': 297, 'language': 'en'}
#
# {'content': '@realDonaldTrump 😁👍Absolutely!', 'contenttype': 'text/plain', 'created': 0, 'id': 298, 'language': 'en'}
#
# ...
#
# {'content': '@KylieJenner 🎵🎶🎵Am I not a good friend so tweet me babe have u tried the donuts 🍩😘😘', 'contenttype': 'text/plain', 'created': 0, 'id': 13413, 'language': 'en'}
#
# {'content': '@MasterCatOG How do you think I feel? How must I go to campus? Are you nuts😭', 'contenttype': 'text/plain', 'created': 0, 'id': 13414, 'language': 'en'}
#
# {'content': "@HinyHumoren 🤣🤣 there's this sound that comes when you swallow such fufu", 'contenttype': 'text/plain', 'created': 0, 'id': 13415, 'language': 'en'}
#
# {'content': '@onebylethcell ...that answer... proves it all...', 'contenttype': 'text/plain', 'created': 0, 'id': 13416, 'language': 'en'}
#
# {'content': '@flauwered yes i am', 'contenttype': 'text/plain', 'created': 0, 'id': 13417, 'language': 'en'}
#
# {'content': 'Is that a hydra!?', 'contenttype': 'text/plain', 'created': 0, 'id': 13418, 'language': 'en'}
#
# {'content': '@adladejon Same lol', 'contenttype': 'text/plain', 'created': 0, 'id': 13419, 'language': 'en'}
#
# {'content': '@CD12LA Resign you pud', 'contenttype': 'text/plain', 'created': 0, 'id': 13420, 'language': 'en'}
#
# {'content': 'Wth is riverdale latest ep', 'contenttype': 'text/plain', 'created': 0, 'id': 13421, 'language': 'en'}
#
# {'content': 'f\n  o\n    l\n     l\n       o\n      w\n\u3000\n    m\n   e\n &amp;\nR\n  T\nhttps://t.co/i4jH5sehOi', 'contenttype': 'text/plain', 'created': 0, 'id': 13422, 'language': 'en'}
#
# {'content': '@jxnnelle_ We don’t talk about it https://t.co/v9r5KsOXdA', 'contenttype': 'text/plain', 'created': 0, 'id': 13423, 'language': 'en'}
#
# {'content': 'You could be more energized with extra enthusiasm for group ac... More for Sagittarius https://t.co/Q3j1ng9GQe', 'contenttype': 'text/plain', 'created': 0, 'id': 13424, 'language': 'en'}
#
# {'content': '@HaliaAndJade thank you! 💖', 'contenttype': 'text/plain', 'created': 0, 'id': 13425, 'language': 'en'}
#
# {'content': "Sun's aesthetic is futurecore!\nThe future is now!\n#shindanmaker\nhttps://t.co/z53SpVM9Vk", 'contenttype': 'text/plain', 'created': 0, 'id': 13426, 'language': 'en'}
#
# {'content': '"Sonic Boom, Sonic Boom (Spinning through a world in motion)" (#SonicBoom Theme) #SonicMusicBot', 'contenttype': 'text/plain', 'created': 0, 'id': 13427, 'language': 'en'}
#
# {'content': 'Bought 0.2 Lots EURUSD 1.13494', 'contenttype': 'text/plain', 'created': 0, 'id': 13428, 'language': 'en'}
#
# {'content': 'HE IS THE FINEST MF TO EVER WALK THIS EARTH. PERIODT. https://t.co/iyRCP085Fi', 'contenttype': 'text/plain', 'created': 0, 'id': 13429, 'language': 'en'}
#
# {'content': '@CD12LA Resign you pud', 'contenttype': 'text/plain', 'created': 0, 'id': 13430, 'language': 'en'}
#
# {'content': 'Wth is riverdale latest ep', 'contenttype': 'text/plain', 'created': 0, 'id': 13431, 'language': 'en'}
#
# {'content': 'f\n  o\n    l\n     l\n       o\n      w\n\u3000\n    m\n   e\n &amp;\nR\n  T\nhttps://t.co/i4jH5sehOi', 'contenttype': 'text/plain', 'created': 0, 'id': 13432, 'language': 'en'}
#
# {'content': '@jxnnelle_ We don’t talk about it https://t.co/v9r5KsOXdA', 'contenttype': 'text/plain', 'created': 0, 'id': 13433, 'language': 'en'}
#
# {'content': 'You could be more energized with extra enthusiasm for group ac... More for Sagittarius https://t.co/Q3j1ng9GQe', 'contenttype': 'text/plain', 'created': 0, 'id': 13434, 'language': 'en'}
#
# {'content': '@HaliaAndJade thank you! 💖', 'contenttype': 'text/plain', 'created': 0, 'id': 13435, 'language': 'en'}
#
# {'content': "Sun's aesthetic is futurecore!\nThe future is now!\n#shindanmaker\nhttps://t.co/z53SpVM9Vk", 'contenttype': 'text/plain', 'created': 0, 'id': 13436, 'language': 'en'}
#
# {'content': '"Sonic Boom, Sonic Boom (Spinning through a world in motion)" (#SonicBoom Theme) #SonicMusicBot', 'contenttype': 'text/plain', 'created': 0, 'id': 13437, 'language': 'en'}
#
# {'content': 'Bought 0.2 Lots EURUSD 1.13494', 'contenttype': 'text/plain', 'created': 0, 'id': 13438, 'language': 'en'}
#
# {'content': 'HE IS THE FINEST MF TO EVER WALK THIS EARTH. PERIODT. https://t.co/iyRCP085Fi', 'contenttype': 'text/plain', 'created': 0, 'id': 13439, 'language': 'en'}
#
# {'content': '@CD12LA Resign you pud', 'contenttype': 'text/plain', 'created': 0, 'id': 13440, 'language': 'en'}
#
# {'content': 'Wth is riverdale latest ep', 'contenttype': 'text/plain', 'created': 0, 'id': 13441, 'language': 'en'}
#
# {'content': 'f\n  o\n    l\n     l\n       o\n      w\n\u3000\n    m\n   e\n &amp;\nR\n  T\nhttps://t.co/i4jH5sehOi', 'contenttype': 'text/plain', 'created': 0, 'id': 13442, 'language': 'en'}
#
# {'content': '@jxnnelle_ We don’t talk about it https://t.co/v9r5KsOXdA', 'contenttype': 'text/plain', 'created': 0, 'id': 13443, 'language': 'en'}
#
# {'content': 'You could be more energized with extra enthusiasm for group ac... More for Sagittarius https://t.co/Q3j1ng9GQe', 'contenttype': 'text/plain', 'created': 0, 'id': 13444, 'language': 'en'}
#
# {'content': '@HaliaAndJade thank you! 💖', 'contenttype': 'text/plain', 'created': 0, 'id': 13445, 'language': 'en'}
#
# {'content': "Sun's aesthetic is futurecore!\nThe future is now!\n#shindanmaker\nhttps://t.co/z53SpVM9Vk", 'contenttype': 'text/plain', 'created': 0, 'id': 13446, 'language': 'en'}
#
# {'content': '"Sonic Boom, Sonic Boom (Spinning through a world in motion)" (#SonicBoom Theme) #SonicMusicBot', 'contenttype': 'text/plain', 'created': 0, 'id': 13447, 'language': 'en'}
#
# {'content': 'Bought 0.2 Lots EURUSD 1.13494', 'contenttype': 'text/plain', 'created': 0, 'id': 13448, 'language': 'en'}
#
# {'content': 'HE IS THE FINEST MF TO EVER WALK THIS EARTH. PERIODT. https://t.co/iyRCP085Fi', 'contenttype': 'text/plain', 'created': 0, 'id': 13449, 'language': 'en'}
#
# {'content': '@mrdanwalker great story about stem cell donation Dan and the way the prof expalined couldn’t have been clearer. My… https://t.co/vcwXlHgcv8', 'contenttype': 'text/plain', 'created': 0, 'id': 13450, 'language': 'en'}
#
# {'content': '@JacksonBrittsny Also then gave you your personal coffee order the day after you rejected him', 'contenttype': 'text/plain', 'created': 0, 'id': 13451, 'language': 'en'}
#
# {'content': "I'm back from the dead. ⚰️", 'contenttype': 'text/plain', 'created': 0, 'id': 13452, 'language': 'en'}
#
# {'content': 'How You Can Make Healthy Living Easier For Your Elderly Parent https://t.co/0VegiylcYS', 'contenttype': 'text/plain', 'created': 0, 'id': 13453, 'language': 'en'}
#
# {'content': '@VictorMochere Why is it a crime for a leader with a government salary to build his wife a nice house? We have accu… https://t.co/ICklkGqDvs', 'contenttype': 'text/plain', 'created': 0, 'id': 13454, 'language': 'en'}
#
# {'content': 'you guys are so cute.', 'contenttype': 'text/plain', 'created': 0, 'id': 13455, 'language': 'en'}
#
# {'content': 'iimag: Twitter Mostly Avoids Stock Market Carnage After $1 Billion Silver Lake Deal https://t.co/Mc39cs3SpS https://t.co/aizWGvMyxq', 'contenttype': 'text/plain', 'created': 0, 'id': 13456, 'language': 'en'}
#
# {'content': '$JAZZ major stock movement -6.89 % change recently https://t.co/OYSuKgraKS', 'contenttype': 'text/plain', 'created': 0, 'id': 13457, 'language': 'en'}
#
# {'content': 'Atheism saves lives. https://t.co/IRpvQnT3JT', 'contenttype': 'text/plain', 'created': 0, 'id': 13458, 'language': 'en'}
#
# {'content': '@lorenbhollander @HollanderJodi @RealPDeLuise My dad’s favorite movie!  😎', 'contenttype': 'text/plain', 'created': 0, 'id': 13459, 'language': 'en'}
#
# {'content': '@mrdanwalker great story about stem cell donation Dan and the way the prof expalined couldn’t have been clearer. My… https://t.co/vcwXlHgcv8', 'contenttype': 'text/plain', 'created': 0, 'id': 13460, 'language': 'en'}
#
# {'content': '@JacksonBrittsny Also then gave you your personal coffee order the day after you rejected him', 'contenttype': 'text/plain', 'created': 0, 'id': 13461, 'language': 'en'}
#
# {'content': "I'm back from the dead. ⚰️", 'contenttype': 'text/plain', 'created': 0, 'id': 13462, 'language': 'en'}
#
# {'content': 'How You Can Make Healthy Living Easier For Your Elderly Parent https://t.co/0VegiylcYS', 'contenttype': 'text/plain', 'created': 0, 'id': 13463, 'language': 'en'}
#
# {'content': '@VictorMochere Why is it a crime for a leader with a government salary to build his wife a nice house? We have accu… https://t.co/ICklkGqDvs', 'contenttype': 'text/plain', 'created': 0, 'id': 13464, 'language': 'en'}
#
# {'content': 'you guys are so cute.', 'contenttype': 'text/plain', 'created': 0, 'id': 13465, 'language': 'en'}
#
# {'content': 'iimag: Twitter Mostly Avoids Stock Market Carnage After $1 Billion Silver Lake Deal https://t.co/Mc39cs3SpS https://t.co/aizWGvMyxq', 'contenttype': 'text/plain', 'created': 0, 'id': 13466, 'language': 'en'}
#
# {'content': '$JAZZ major stock movement -6.89 % change recently https://t.co/OYSuKgraKS', 'contenttype': 'text/plain', 'created': 0, 'id': 13467, 'language': 'en'}
#
# {'content': 'Atheism saves lives. https://t.co/IRpvQnT3JT', 'contenttype': 'text/plain', 'created': 0, 'id': 13468, 'language': 'en'}
#
# {'content': '@lorenbhollander @HollanderJodi @RealPDeLuise My dad’s favorite movie!  😎', 'contenttype': 'text/plain', 'created': 0, 'id': 13469, 'language': 'en'}
#
# {'content': '@mrdanwalker great story about stem cell donation Dan and the way the prof expalined couldn’t have been clearer. My… https://t.co/vcwXlHgcv8', 'contenttype': 'text/plain', 'created': 0, 'id': 13470, 'language': 'en'}
#
# {'content': '@JacksonBrittsny Also then gave you your personal coffee order the day after you rejected him', 'contenttype': 'text/plain', 'created': 0, 'id': 13471, 'language': 'en'}
#
# {'content': "I'm back from the dead. ⚰️", 'contenttype': 'text/plain', 'created': 0, 'id': 13472, 'language': 'en'}
#
# {'content': 'How You Can Make Healthy Living Easier For Your Elderly Parent https://t.co/0VegiylcYS', 'contenttype': 'text/plain', 'created': 0, 'id': 13473, 'language': 'en'}
#
# {'content': '@VictorMochere Why is it a crime for a leader with a government salary to build his wife a nice house? We have accu… https://t.co/ICklkGqDvs', 'contenttype': 'text/plain', 'created': 0, 'id': 13474, 'language': 'en'}
#
# {'content': 'you guys are so cute.', 'contenttype': 'text/plain', 'created': 0, 'id': 13475, 'language': 'en'}
#
# {'content': 'iimag: Twitter Mostly Avoids Stock Market Carnage After $1 Billion Silver Lake Deal https://t.co/Mc39cs3SpS https://t.co/aizWGvMyxq', 'contenttype': 'text/plain', 'created': 0, 'id': 13476, 'language': 'en'}
#
# {'content': '$JAZZ major stock movement -6.89 % change recently https://t.co/OYSuKgraKS', 'contenttype': 'text/plain', 'created': 0, 'id': 13477, 'language': 'en'}
#
# {'content': 'Atheism saves lives. https://t.co/IRpvQnT3JT', 'contenttype': 'text/plain', 'created': 0, 'id': 13478, 'language': 'en'}
#
# {'content': '@lorenbhollander @HollanderJodi @RealPDeLuise My dad’s favorite movie!  😎', 'contenttype': 'text/plain', 'created': 0, 'id': 13479, 'language': 'en'}
#
# {'content': 'The value of some of your important relationships comes into f... More for Virgo https://t.co/guyJyc2RG9', 'contenttype': 'text/plain', 'created': 0, 'id': 13480, 'language': 'en'}
#
# {'content': '@AllRoyaltweets1 @Slindoza @SussexInspired Meghan looked away first.', 'contenttype': 'text/plain', 'created': 0, 'id': 13481, 'language': 'en'}
#
# {'content': '@brooklynnygirl @JoeBiden I understand your frustration if Sanders is not picked but why turn your back on your par… https://t.co/Jq6pWl7rKu', 'contenttype': 'text/plain', 'created': 0, 'id': 13482, 'language': 'en'}
#
# {'content': '@JM_Scindia #jyotiraditya Toh jhaanki hai #SachinPilot abhi baaki hai! 😊🙏\nKudos to the power of youth! \nTime to Unl… https://t.co/JXxg1KBVdn', 'contenttype': 'text/plain', 'created': 0, 'id': 13483, 'language': 'en'}
#
# {'content': 'Fun and romance are on the agenda once the Moon enters Libra a... More for Gemini https://t.co/eGzZdroWkm', 'contenttype': 'text/plain', 'created': 0, 'id': 13484, 'language': 'en'}
#
# {'content': '@imyourseesaw Morning \U0001f97a', 'contenttype': 'text/plain', 'created': 0, 'id': 13485, 'language': 'en'}
#
# {'content': "@cassiebearbear1 I'm gonna need you to not cause das a lie and you know it", 'contenttype': 'text/plain', 'created': 0, 'id': 13486, 'language': 'en'}
#
# {'content': "@MisterAlbie I'm not in the mood for jokes.", 'contenttype': 'text/plain', 'created': 0, 'id': 13487, 'language': 'en'}
#
# {'content': 'i will always pray for u', 'contenttype': 'text/plain', 'created': 0, 'id': 13488, 'language': 'en'}
#
# {'content': '@BigMan_Xander Money heist', 'contenttype': 'text/plain', 'created': 0, 'id': 13489, 'language': 'en'}
#
# {'content': 'The value of some of your important relationships comes into f... More for Virgo https://t.co/guyJyc2RG9', 'contenttype': 'text/plain', 'created': 0, 'id': 13490, 'language': 'en'}
#
# {'content': '@AllRoyaltweets1 @Slindoza @SussexInspired Meghan looked away first.', 'contenttype': 'text/plain', 'created': 0, 'id': 13491, 'language': 'en'}
#
# {'content': '@brooklynnygirl @JoeBiden I understand your frustration if Sanders is not picked but why turn your back on your par… https://t.co/Jq6pWl7rKu', 'contenttype': 'text/plain', 'created': 0, 'id': 13492, 'language': 'en'}
#
# {'content': '@JM_Scindia #jyotiraditya Toh jhaanki hai #SachinPilot abhi baaki hai! 😊🙏\nKudos to the power of youth! \nTime to Unl… https://t.co/JXxg1KBVdn', 'contenttype': 'text/plain', 'created': 0, 'id': 13493, 'language': 'en'}
#
# {'content': 'Fun and romance are on the agenda once the Moon enters Libra a... More for Gemini https://t.co/eGzZdroWkm', 'contenttype': 'text/plain', 'created': 0, 'id': 13494, 'language': 'en'}
#
# {'content': '@imyourseesaw Morning \U0001f97a', 'contenttype': 'text/plain', 'created': 0, 'id': 13495, 'language': 'en'}
#
# {'content': "@cassiebearbear1 I'm gonna need you to not cause das a lie and you know it", 'contenttype': 'text/plain', 'created': 0, 'id': 13496, 'language': 'en'}
#
# {'content': "@MisterAlbie I'm not in the mood for jokes.", 'contenttype': 'text/plain', 'created': 0, 'id': 13497, 'language': 'en'}
#
# {'content': 'i will always pray for u', 'contenttype': 'text/plain', 'created': 0, 'id': 13498, 'language': 'en'}
#
# {'content': '@BigMan_Xander Money heist', 'contenttype': 'text/plain', 'created': 0, 'id': 13499, 'language': 'en'}
#
# {'content': 'The value of some of your important relationships comes into f... More for Virgo https://t.co/guyJyc2RG9', 'contenttype': 'text/plain', 'created': 0, 'id': 13500, 'language': 'en'}
#
# {'content': '@AllRoyaltweets1 @Slindoza @SussexInspired Meghan looked away first.', 'contenttype': 'text/plain', 'created': 0, 'id': 13501, 'language': 'en'}
#
# {'content': '@brooklynnygirl @JoeBiden I understand your frustration if Sanders is not picked but why turn your back on your par… https://t.co/Jq6pWl7rKu', 'contenttype': 'text/plain', 'created': 0, 'id': 13502, 'language': 'en'}
#
# {'content': '@JM_Scindia #jyotiraditya Toh jhaanki hai #SachinPilot abhi baaki hai! 😊🙏\nKudos to the power of youth! \nTime to Unl… https://t.co/JXxg1KBVdn', 'contenttype': 'text/plain', 'created': 0, 'id': 13503, 'language': 'en'}
#
# {'content': 'Fun and romance are on the agenda once the Moon enters Libra a... More for Gemini https://t.co/eGzZdroWkm', 'contenttype': 'text/plain', 'created': 0, 'id': 13504, 'language': 'en'}
#
# {'content': '@imyourseesaw Morning \U0001f97a', 'contenttype': 'text/plain', 'created': 0, 'id': 13505, 'language': 'en'}
#
# {'content': "@cassiebearbear1 I'm gonna need you to not cause das a lie and you know it", 'contenttype': 'text/plain', 'created': 0, 'id': 13506, 'language': 'en'}
#
# {'content': "@MisterAlbie I'm not in the mood for jokes.", 'contenttype': 'text/plain', 'created': 0, 'id': 13507, 'language': 'en'}
#
# {'content': 'i will always pray for u', 'contenttype': 'text/plain', 'created': 0, 'id': 13508, 'language': 'en'}
#
# {'content': '@BigMan_Xander Money heist', 'contenttype': 'text/plain', 'created': 0, 'id': 13509, 'language': 'en'}

# %%
dlist
# Out:
# [{'content': '@theinstantwin @JKDAnthony10 @grantstern @TheDemCoalition Because they’d be prosecuting government officials?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 0,
#   'language': 'en'},
#  {'content': '@SailorZZtar It’s actually cheaper to eat on the right. That’s multiple days worth of food. The McD’s is just one meal during the day',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 1,
#   'language': 'en'},
#  {'content': '@tedlieu The same thing can be said of you as you attended AIPAC, where one attendee, and likely others, were and w… https://t.co/pgLaDT5IgS',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 2,
#   'language': 'en'},
#  {'content': '👇🏼I see nothing but facts! https://t.co/9Xgw5RVmNU',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 3,
#   'language': 'en'},
#  {'content': '"Omg we lost an hour on international womans day." Omfg shut up. Daylights savings time is not always on internatio… https://t.co/36cVsIqlfb',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 4,
#   'language': 'en'},
#  {'content': '@bbymochimini Me too :(((',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 5,
#   'language': 'en'},
#  {'content': 'I’m so tired of being tired of being tired',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 6,
#   'language': 'en'},
#  {'content': '@cardisexual It still works wtffhfgeyds',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 7,
#   'language': 'en'},
#  {'content': 'I’m dead https://t.co/u25ePn2pkb',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 8,
#   'language': 'en'},
#  {'content': '@TheRealAnnabel_ Thats normal mos',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 9,
#   'language': 'en'},
#  {'content': 'hatchet pussy be hittin different',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 10,
#   'language': 'en'},
#  {'content': '@sandra_wynkoop With Cruz!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 11,
#   'language': 'en'},
#  {'content': 'Just passed by a house with their icicle lights and wreath still up.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 12,
#   'language': 'en'},
#  {'content': '@BranfordJones5 😂new day tomorrow',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 13,
#   'language': 'en'},
#  {'content': '@chafin99 @DraedaVenorik @InfinityWard True! My only day off was yesterday and I wanted to level up, cause I wanna… https://t.co/OqjWFyLvLH',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 14,
#   'language': 'en'},
#  {'content': 'Concerned about the #coronavirus (COVID-19)? Check out our resource page here: https://t.co/Gq0gP7WkLM https://t.co/CmONX2YQW6',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 15,
#   'language': 'en'},
#  {'content': 'the starbucks barista misheard my name and now everyone in this place is gunna think my name is martha. don’t hmu😔',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 16,
#   'language': 'en'},
#  {'content': 'Say it with me: namjoon prettiest boy @BTS_twt\n#iHeartAwards #BestMusicVideo #BoyWithLuv #BTSRM\nhttps://t.co/vJcQFn5BiH',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 17,
#   'language': 'en'},
#  {'content': '@BeyondBeautiful Who cares',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 18,
#   'language': 'en'},
#  {'content': 'Good afternoon, Cyber Defenders!! Web Recon anyone?? “Final Recon - OSINT Tool for All-In-One Web Reconnaissance”… https://t.co/vj4ZwvCBnE',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 19,
#   'language': 'en'},
#  {'content': 'hatchet pussy be hittin different',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 20,
#   'language': 'en'},
#  {'content': '@sandra_wynkoop With Cruz!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 21,
#   'language': 'en'},
#  {'content': 'Just passed by a house with their icicle lights and wreath still up.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 22,
#   'language': 'en'},
#  {'content': '@BranfordJones5 😂new day tomorrow',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 23,
#   'language': 'en'},
#  {'content': '@chafin99 @DraedaVenorik @InfinityWard True! My only day off was yesterday and I wanted to level up, cause I wanna… https://t.co/OqjWFyLvLH',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 24,
#   'language': 'en'},
#  {'content': 'Concerned about the #coronavirus (COVID-19)? Check out our resource page here: https://t.co/Gq0gP7WkLM https://t.co/CmONX2YQW6',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 25,
#   'language': 'en'},
#  {'content': 'the starbucks barista misheard my name and now everyone in this place is gunna think my name is martha. don’t hmu😔',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 26,
#   'language': 'en'},
#  {'content': 'Say it with me: namjoon prettiest boy @BTS_twt\n#iHeartAwards #BestMusicVideo #BoyWithLuv #BTSRM\nhttps://t.co/vJcQFn5BiH',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 27,
#   'language': 'en'},
#  {'content': '@BeyondBeautiful Who cares',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 28,
#   'language': 'en'},
#  {'content': 'Good afternoon, Cyber Defenders!! Web Recon anyone?? “Final Recon - OSINT Tool for All-In-One Web Reconnaissance”… https://t.co/vj4ZwvCBnE',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 29,
#   'language': 'en'},
#  {'content': '@dar_ruga @EstherBirungi4 Equity not equality would make more sense\nHusband is head both biblically and historicall… https://t.co/Op4JFvztTI',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 30,
#   'language': 'en'},
#  {'content': "@mathew05538141 @charliekirk11 @Twitter @TwitterSupport Well I'm a gen-xer but okay.  I realize people like you are… https://t.co/jKJpqg2cu3",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 31,
#   'language': 'en'},
#  {'content': '@blinkwluv @itzyse she suprisingly got more than yeji?? and yeji had so many lines yet was still last in screen time',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 32,
#   'language': 'en'},
#  {'content': '@skinny_que My YT GF two weeks later, after I shaved her head during the night for fucking up my waves. https://t.co/ARsmtHpZO3',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 33,
#   'language': 'en'},
#  {'content': 'Pick up the goat https://t.co/fXWrOnTfKK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 34,
#   'language': 'en'},
#  {'content': 'i always knew cruises were bad news',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 35,
#   'language': 'en'},
#  {'content': '@EliStokols @Stonekettle If Trump dies of COVID-19 I will start going to church again.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 36,
#   'language': 'en'},
#  {'content': "U have said it out, she has😋😋😋while u don't😎😎 https://t.co/3xbVCsyn3M",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 37,
#   'language': 'en'},
#  {'content': 'Claret shorts 😍 #AVFC',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 38,
#   'language': 'en'},
#  {'content': 'Escaping polygamy 😯',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 39,
#   'language': 'en'},
#  {'content': '@dar_ruga @EstherBirungi4 Equity not equality would make more sense\nHusband is head both biblically and historicall… https://t.co/Op4JFvztTI',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 40,
#   'language': 'en'},
#  {'content': "@mathew05538141 @charliekirk11 @Twitter @TwitterSupport Well I'm a gen-xer but okay.  I realize people like you are… https://t.co/jKJpqg2cu3",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 41,
#   'language': 'en'},
#  {'content': '@blinkwluv @itzyse she suprisingly got more than yeji?? and yeji had so many lines yet was still last in screen time',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 42,
#   'language': 'en'},
#  {'content': '@skinny_que My YT GF two weeks later, after I shaved her head during the night for fucking up my waves. https://t.co/ARsmtHpZO3',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 43,
#   'language': 'en'},
#  {'content': 'Pick up the goat https://t.co/fXWrOnTfKK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 44,
#   'language': 'en'},
#  {'content': 'i always knew cruises were bad news',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 45,
#   'language': 'en'},
#  {'content': '@EliStokols @Stonekettle If Trump dies of COVID-19 I will start going to church again.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 46,
#   'language': 'en'},
#  {'content': "U have said it out, she has😋😋😋while u don't😎😎 https://t.co/3xbVCsyn3M",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 47,
#   'language': 'en'},
#  {'content': 'Claret shorts 😍 #AVFC',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 48,
#   'language': 'en'},
#  {'content': 'Escaping polygamy 😯',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 49,
#   'language': 'en'},
#  {'content': '@dar_ruga @EstherBirungi4 Equity not equality would make more sense\nHusband is head both biblically and historicall… https://t.co/Op4JFvztTI',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 50,
#   'language': 'en'},
#  {'content': "@mathew05538141 @charliekirk11 @Twitter @TwitterSupport Well I'm a gen-xer but okay.  I realize people like you are… https://t.co/jKJpqg2cu3",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 51,
#   'language': 'en'},
#  {'content': '@blinkwluv @itzyse she suprisingly got more than yeji?? and yeji had so many lines yet was still last in screen time',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 52,
#   'language': 'en'},
#  {'content': '@skinny_que My YT GF two weeks later, after I shaved her head during the night for fucking up my waves. https://t.co/ARsmtHpZO3',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 53,
#   'language': 'en'},
#  {'content': 'Pick up the goat https://t.co/fXWrOnTfKK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 54,
#   'language': 'en'},
#  {'content': 'i always knew cruises were bad news',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 55,
#   'language': 'en'},
#  {'content': '@EliStokols @Stonekettle If Trump dies of COVID-19 I will start going to church again.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 56,
#   'language': 'en'},
#  {'content': "U have said it out, she has😋😋😋while u don't😎😎 https://t.co/3xbVCsyn3M",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 57,
#   'language': 'en'},
#  {'content': 'Claret shorts 😍 #AVFC',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 58,
#   'language': 'en'},
#  {'content': 'Escaping polygamy 😯',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 59,
#   'language': 'en'},
#  {'content': 'Whoever invented daylight savings I’m gonna shatter your knees https://t.co/DvIMzrY6tR',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 60,
#   'language': 'en'},
#  {'content': '@Khan_Maximuss @VipArsenal Not really, oflate lacazetteris shitty Ozil not influential at all!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 61,
#   'language': 'en'},
#  {'content': '@LovattMo @_HelenDale @jonnnybest @allisonpearson @darrengrimes_ His defence was he was suffering from the kimonovirus',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 62,
#   'language': 'en'},
#  {'content': 'Don’t I know it?!! Lol ❤️💪🏽 https://t.co/4737qHrzxI',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 63,
#   'language': 'en'},
#  {'content': 'https://t.co/2ZNrlx9RsL\ndoesn’t stop them from closing the entire school district i’m in for two weeks..not one per… https://t.co/sJgqZdQBGF',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 64,
#   'language': 'en'},
#  {'content': '@chyumiin I felt like i went to another dimension',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 65,
#   'language': 'en'},
#  {'content': 'June 2019 - Spain Rolls Out #5G Network Using #Huawei Gear\n \nhttps://t.co/aHdGYgjpRu\n\nMarch 2020 - Spain shuts scho… https://t.co/2d6tMCHesB',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 66,
#   'language': 'en'},
#  {'content': '#LOUIS: y’all dumb sorry',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 67,
#   'language': 'en'},
#  {'content': '@BasTheGREAT5 Facts!!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 68,
#   'language': 'en'},
#  {'content': 'YESS YES YESS https://t.co/rvMlUNX52F',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 69,
#   'language': 'en'},
#  {'content': 'Whoever invented daylight savings I’m gonna shatter your knees https://t.co/DvIMzrY6tR',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 70,
#   'language': 'en'},
#  {'content': '@Khan_Maximuss @VipArsenal Not really, oflate lacazetteris shitty Ozil not influential at all!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 71,
#   'language': 'en'},
#  {'content': '@LovattMo @_HelenDale @jonnnybest @allisonpearson @darrengrimes_ His defence was he was suffering from the kimonovirus',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 72,
#   'language': 'en'},
#  {'content': 'Don’t I know it?!! Lol ❤️💪🏽 https://t.co/4737qHrzxI',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 73,
#   'language': 'en'},
#  {'content': 'https://t.co/2ZNrlx9RsL\ndoesn’t stop them from closing the entire school district i’m in for two weeks..not one per… https://t.co/sJgqZdQBGF',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 74,
#   'language': 'en'},
#  {'content': '@chyumiin I felt like i went to another dimension',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 75,
#   'language': 'en'},
#  {'content': 'June 2019 - Spain Rolls Out #5G Network Using #Huawei Gear\n \nhttps://t.co/aHdGYgjpRu\n\nMarch 2020 - Spain shuts scho… https://t.co/2d6tMCHesB',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 76,
#   'language': 'en'},
#  {'content': '#LOUIS: y’all dumb sorry',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 77,
#   'language': 'en'},
#  {'content': '@BasTheGREAT5 Facts!!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 78,
#   'language': 'en'},
#  {'content': 'YESS YES YESS https://t.co/rvMlUNX52F',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 79,
#   'language': 'en'},
#  {'content': '@PATisDOPE 8.5 and what’s the website brody... Those pants are needed in the rotation',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 80,
#   'language': 'en'},
#  {'content': '@_YorkshireRose_ I bet their spare room is currently crammed full of toilet rolls, hand gel and pasta',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 81,
#   'language': 'en'},
#  {'content': '@tsn_wally @ian_mendes We wanted #Melnyk out and we’re getting #everyoneexceptMelnykout',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 82,
#   'language': 'en'},
#  {'content': '@svtgaara blackpink e bts\nhttps://t.co/i1wJxKlT9I',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 83,
#   'language': 'en'},
#  {'content': '@Natnai_ Serial killer activity 💀',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 84,
#   'language': 'en'},
#  {'content': 'jimin popping is so powerful,sharp and hot ooof\nhttps://t.co/jqMB9eRzgv',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 85,
#   'language': 'en'},
#  {'content': "@PrincessLilyMTG Have you considered adding this card to your MTG cube? It's essentially a free draw since it only… https://t.co/UAEP5TQ3do",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 86,
#   'language': 'en'},
#  {'content': 'We Continue To Rebuke The Propaganda Evil False Media!\nIn Jesus’s Name!\nAmen https://t.co/yof9io4qcK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 87,
#   'language': 'en'},
#  {'content': '@leahcaitlin1234 Can’t wait 💗',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 88,
#   'language': 'en'},
#  {'content': '@bmanclaus Story time?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 89,
#   'language': 'en'},
#  {'content': '@PATisDOPE 8.5 and what’s the website brody... Those pants are needed in the rotation',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 90,
#   'language': 'en'},
#  {'content': '@_YorkshireRose_ I bet their spare room is currently crammed full of toilet rolls, hand gel and pasta',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 91,
#   'language': 'en'},
#  {'content': '@tsn_wally @ian_mendes We wanted #Melnyk out and we’re getting #everyoneexceptMelnykout',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 92,
#   'language': 'en'},
#  {'content': '@Natnai_ Serial killer activity 💀',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 93,
#   'language': 'en'},
#  {'content': 'jimin popping is so powerful,sharp and hot ooof\nhttps://t.co/jqMB9eRzgv',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 94,
#   'language': 'en'},
#  {'content': "@PrincessLilyMTG Have you considered adding this card to your MTG cube? It's essentially a free draw since it only… https://t.co/UAEP5TQ3do",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 95,
#   'language': 'en'},
#  {'content': 'We Continue To Rebuke The Propaganda Evil False Media!\nIn Jesus’s Name!\nAmen https://t.co/yof9io4qcK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 96,
#   'language': 'en'},
#  {'content': '@leahcaitlin1234 Can’t wait 💗',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 97,
#   'language': 'en'},
#  {'content': '@bmanclaus Story time?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 98,
#   'language': 'en'},
#  {'content': "@realDonaldTrump you need to be tested for COVID-19. Don't pass it to your wife and Barron.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 99,
#   'language': 'en'},
#  {'content': '@PATisDOPE 8.5 and what’s the website brody... Those pants are needed in the rotation',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 100,
#   'language': 'en'},
#  {'content': '@_YorkshireRose_ I bet their spare room is currently crammed full of toilet rolls, hand gel and pasta',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 101,
#   'language': 'en'},
#  {'content': '@tsn_wally @ian_mendes We wanted #Melnyk out and we’re getting #everyoneexceptMelnykout',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 102,
#   'language': 'en'},
#  {'content': '@Natnai_ Serial killer activity 💀',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 103,
#   'language': 'en'},
#  {'content': 'jimin popping is so powerful,sharp and hot ooof\nhttps://t.co/jqMB9eRzgv',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 104,
#   'language': 'en'},
#  {'content': "@PrincessLilyMTG Have you considered adding this card to your MTG cube? It's essentially a free draw since it only… https://t.co/UAEP5TQ3do",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 105,
#   'language': 'en'},
#  {'content': 'We Continue To Rebuke The Propaganda Evil False Media!\nIn Jesus’s Name!\nAmen https://t.co/yof9io4qcK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 106,
#   'language': 'en'},
#  {'content': '@leahcaitlin1234 Can’t wait 💗',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 107,
#   'language': 'en'},
#  {'content': '@bmanclaus Story time?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 108,
#   'language': 'en'},
#  {'content': "@realDonaldTrump you need to be tested for COVID-19. Don't pass it to your wife and Barron.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 109,
#   'language': 'en'},
#  {'content': '@NuthinOnBartee I’ll be there end end of April tho. Flight was booked yesterday.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 110,
#   'language': 'en'},
#  {'content': "@Breaking911 I'm shocked the gas mask didn't work! 😂",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 111,
#   'language': 'en'},
#  {'content': '@PatPenn2 @FLAGDEFENDER1 Soros is the anrichrist',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 112,
#   'language': 'en'},
#  {'content': '@ObeseGiraffeYT Is this legit? What’s the method?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 113,
#   'language': 'en'},
#  {'content': 'dang is EVERYONE in Punta Cana rn \U0001f97a',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 114,
#   'language': 'en'},
#  {'content': '@Meche____ @Bujutoyourears Afro fusion legend🙌',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 115,
#   'language': 'en'},
#  {'content': '@sojapojke Needle holder?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 116,
#   'language': 'en'},
#  {'content': 'i am trans ..... lucent .',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 117,
#   'language': 'en'},
#  {'content': '@xoxobitchzz Its only the truth, theres no need',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 118,
#   'language': 'en'},
#  {'content': "Hadn't seen it for myself until this morning, quite sad when you go to supermarket to get some bread and milk as it… https://t.co/CtrVmeO5V4",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 119,
#   'language': 'en'},
#  {'content': '@NuthinOnBartee I’ll be there end end of April tho. Flight was booked yesterday.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 120,
#   'language': 'en'},
#  {'content': "@Breaking911 I'm shocked the gas mask didn't work! 😂",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 121,
#   'language': 'en'},
#  {'content': '@PatPenn2 @FLAGDEFENDER1 Soros is the anrichrist',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 122,
#   'language': 'en'},
#  {'content': '@ObeseGiraffeYT Is this legit? What’s the method?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 123,
#   'language': 'en'},
#  {'content': 'dang is EVERYONE in Punta Cana rn \U0001f97a',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 124,
#   'language': 'en'},
#  {'content': '@Meche____ @Bujutoyourears Afro fusion legend🙌',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 125,
#   'language': 'en'},
#  {'content': '@sojapojke Needle holder?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 126,
#   'language': 'en'},
#  {'content': 'i am trans ..... lucent .',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 127,
#   'language': 'en'},
#  {'content': '@xoxobitchzz Its only the truth, theres no need',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 128,
#   'language': 'en'},
#  {'content': "Hadn't seen it for myself until this morning, quite sad when you go to supermarket to get some bread and milk as it… https://t.co/CtrVmeO5V4",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 129,
#   'language': 'en'},
#  {'content': '@NuthinOnBartee I’ll be there end end of April tho. Flight was booked yesterday.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 130,
#   'language': 'en'},
#  {'content': "@Breaking911 I'm shocked the gas mask didn't work! 😂",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 131,
#   'language': 'en'},
#  {'content': '@PatPenn2 @FLAGDEFENDER1 Soros is the anrichrist',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 132,
#   'language': 'en'},
#  {'content': '@ObeseGiraffeYT Is this legit? What’s the method?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 133,
#   'language': 'en'},
#  {'content': 'dang is EVERYONE in Punta Cana rn \U0001f97a',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 134,
#   'language': 'en'},
#  {'content': '@Meche____ @Bujutoyourears Afro fusion legend🙌',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 135,
#   'language': 'en'},
#  {'content': '@sojapojke Needle holder?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 136,
#   'language': 'en'},
#  {'content': 'i am trans ..... lucent .',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 137,
#   'language': 'en'},
#  {'content': '@xoxobitchzz Its only the truth, theres no need',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 138,
#   'language': 'en'},
#  {'content': "Hadn't seen it for myself until this morning, quite sad when you go to supermarket to get some bread and milk as it… https://t.co/CtrVmeO5V4",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 139,
#   'language': 'en'},
#  {'content': 'What if I have a matron AND a maid of honor',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 140,
#   'language': 'en'},
#  {'content': '@Themba93132630 Eish bro you will be rich yhooo https://t.co/U9jqIXmy8Z',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 141,
#   'language': 'en'},
#  {'content': '@KindestLotus A lot? •u•)',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 142,
#   'language': 'en'},
#  {'content': '@CurtisGCracker 👀 I wanna do this too! \nAs for the horns, I wanna see double horns, kinda like a crown?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 143,
#   'language': 'en'},
#  {'content': 'Quick, simple to prepare and packed full of delicious Mexican flavours, these Easy Beef Enchiladas are the perfect… https://t.co/Tfxwlts9Ei',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 144,
#   'language': 'en'},
#  {'content': 'My 4 year old and I were at the store and pointing to the cologne in the glass cabinet she asked me what it was, I… https://t.co/NyAreomOQ1',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 145,
#   'language': 'en'},
#  {'content': '@Angellight4u Congratulations!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 146,
#   'language': 'en'},
#  {'content': "@bayesianboy Yes. See Marcel Quarfood's dissertation or book. Think I got the spelling right. Or other refs to him.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 147,
#   'language': 'en'},
#  {'content': "@KatherineWyvern Yes if I were a young maiden gone down to bathe in the forest pool and I saw him, I'd be very afra… https://t.co/IBmbpy2Y8v",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 148,
#   'language': 'en'},
#  {'content': '@realDonaldTrump This is not a fire &amp; forget crisis mate. Don’t pat yourself on the back for 1 early decision that… https://t.co/YuJSO07Q9X',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 149,
#   'language': 'en'},
#  {'content': 'Food always puts me in a good mood',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 150,
#   'language': 'en'},
#  {'content': "@donachaidh She's hot tho",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 151,
#   'language': 'en'},
#  {'content': '@P0A_Triot23 11:39 am EDT, 03/09/2020\nW H R A C 4D ...\n\nH A C D A W I T .\n5D H W C .\nA (TOGETHER) N .',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 152,
#   'language': 'en'},
#  {'content': '$SNCR NEW ARTICLE : Synchronoss reports mixed Q4 results https://t.co/QMRllX5z1n Get all the latest $SNCR related n… https://t.co/bmxyuZzby7',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 153,
#   'language': 'en'},
#  {'content': '@bersuozr @fattyyyma Shouq wallah same😳😳😳',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 154,
#   'language': 'en'},
#  {'content': 'holy shit cumali is right behind cagatay #içerde',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 155,
#   'language': 'en'},
#  {'content': 'DAN RIGHTS https://t.co/nVmcMNkAj2',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 156,
#   'language': 'en'},
#  {'content': 'Go lakers nice back to back wins...35 years old? You don’t say',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 157,
#   'language': 'en'},
#  {'content': '@area51elvis @Queeni_Martini @prayingmedic Just when it goes up, it is Obama\'s "good work"???? lol',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 158,
#   'language': 'en'},
#  {'content': 'Part-time Brand Ambassador positions are available in the following locations: \u2063\nIllinois - Lake/McHenry/Kane Count… https://t.co/TS7qb5L43I',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 159,
#   'language': 'en'},
#  {'content': 'Food always puts me in a good mood',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 160,
#   'language': 'en'},
#  {'content': "@donachaidh She's hot tho",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 161,
#   'language': 'en'},
#  {'content': '@P0A_Triot23 11:39 am EDT, 03/09/2020\nW H R A C 4D ...\n\nH A C D A W I T .\n5D H W C .\nA (TOGETHER) N .',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 162,
#   'language': 'en'},
#  {'content': '$SNCR NEW ARTICLE : Synchronoss reports mixed Q4 results https://t.co/QMRllX5z1n Get all the latest $SNCR related n… https://t.co/bmxyuZzby7',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 163,
#   'language': 'en'},
#  {'content': '@bersuozr @fattyyyma Shouq wallah same😳😳😳',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 164,
#   'language': 'en'},
#  {'content': 'holy shit cumali is right behind cagatay #içerde',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 165,
#   'language': 'en'},
#  {'content': 'DAN RIGHTS https://t.co/nVmcMNkAj2',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 166,
#   'language': 'en'},
#  {'content': 'Go lakers nice back to back wins...35 years old? You don’t say',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 167,
#   'language': 'en'},
#  {'content': '@area51elvis @Queeni_Martini @prayingmedic Just when it goes up, it is Obama\'s "good work"???? lol',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 168,
#   'language': 'en'},
#  {'content': 'Part-time Brand Ambassador positions are available in the following locations: \u2063\nIllinois - Lake/McHenry/Kane Count… https://t.co/TS7qb5L43I',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 169,
#   'language': 'en'},
#  {'content': 'Food always puts me in a good mood',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 170,
#   'language': 'en'},
#  {'content': "@donachaidh She's hot tho",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 171,
#   'language': 'en'},
#  {'content': '@P0A_Triot23 11:39 am EDT, 03/09/2020\nW H R A C 4D ...\n\nH A C D A W I T .\n5D H W C .\nA (TOGETHER) N .',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 172,
#   'language': 'en'},
#  {'content': '$SNCR NEW ARTICLE : Synchronoss reports mixed Q4 results https://t.co/QMRllX5z1n Get all the latest $SNCR related n… https://t.co/bmxyuZzby7',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 173,
#   'language': 'en'},
#  {'content': '@bersuozr @fattyyyma Shouq wallah same😳😳😳',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 174,
#   'language': 'en'},
#  {'content': 'holy shit cumali is right behind cagatay #içerde',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 175,
#   'language': 'en'},
#  {'content': 'DAN RIGHTS https://t.co/nVmcMNkAj2',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 176,
#   'language': 'en'},
#  {'content': 'Go lakers nice back to back wins...35 years old? You don’t say',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 177,
#   'language': 'en'},
#  {'content': '@area51elvis @Queeni_Martini @prayingmedic Just when it goes up, it is Obama\'s "good work"???? lol',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 178,
#   'language': 'en'},
#  {'content': 'Part-time Brand Ambassador positions are available in the following locations: \u2063\nIllinois - Lake/McHenry/Kane Count… https://t.co/TS7qb5L43I',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 179,
#   'language': 'en'},
#  {'content': 'also i could appreciate getting crystals too.. need spark funds onegai shimaku',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 180,
#   'language': 'en'},
#  {'content': '@Kamto_U @Etin_joe I can see you stressed out and you keep calling',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 181,
#   'language': 'en'},
#  {'content': 'Good thing that Jungkook is wearing his baseball cap, and Yanna was too frightened to look at her savior so JK took… https://t.co/znWJjTnAGK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 182,
#   'language': 'en'},
#  {'content': "you know i'm ur type RIGHT?",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 183,
#   'language': 'en'},
#  {'content': '@david_tzatziki I gasped',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 184,
#   'language': 'en'},
#  {'content': "@deepadoc @IshitaYadav That's getting worst now",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 185,
#   'language': 'en'},
#  {'content': '@Lizkthequeen @EstherBirungi4 I’m fine dear. You? \nHaza ndimu mpora mpora',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 186,
#   'language': 'en'},
#  {'content': '@YG_Drag @VIZMedia @HxHSource I THOUGHT I WAS THE ONLY ONE',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 187,
#   'language': 'en'},
#  {'content': 'See my gf and spoil the homies https://t.co/KjcNLHrKTq',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 188,
#   'language': 'en'},
#  {'content': '@HakuPamfer Man that’s awful :(',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 189,
#   'language': 'en'},
#  {'content': 'also i could appreciate getting crystals too.. need spark funds onegai shimaku',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 190,
#   'language': 'en'},
#  {'content': '@Kamto_U @Etin_joe I can see you stressed out and you keep calling',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 191,
#   'language': 'en'},
#  {'content': 'Good thing that Jungkook is wearing his baseball cap, and Yanna was too frightened to look at her savior so JK took… https://t.co/znWJjTnAGK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 192,
#   'language': 'en'},
#  {'content': "you know i'm ur type RIGHT?",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 193,
#   'language': 'en'},
#  {'content': '@david_tzatziki I gasped',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 194,
#   'language': 'en'},
#  {'content': "@deepadoc @IshitaYadav That's getting worst now",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 195,
#   'language': 'en'},
#  {'content': '@Lizkthequeen @EstherBirungi4 I’m fine dear. You? \nHaza ndimu mpora mpora',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 196,
#   'language': 'en'},
#  {'content': '@YG_Drag @VIZMedia @HxHSource I THOUGHT I WAS THE ONLY ONE',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 197,
#   'language': 'en'},
#  {'content': 'See my gf and spoil the homies https://t.co/KjcNLHrKTq',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 198,
#   'language': 'en'},
#  {'content': '@HakuPamfer Man that’s awful :(',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 199,
#   'language': 'en'},
#  {'content': 'also i could appreciate getting crystals too.. need spark funds onegai shimaku',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 200,
#   'language': 'en'},
#  {'content': '@Kamto_U @Etin_joe I can see you stressed out and you keep calling',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 201,
#   'language': 'en'},
#  {'content': 'Good thing that Jungkook is wearing his baseball cap, and Yanna was too frightened to look at her savior so JK took… https://t.co/znWJjTnAGK',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 202,
#   'language': 'en'},
#  {'content': "you know i'm ur type RIGHT?",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 203,
#   'language': 'en'},
#  {'content': '@david_tzatziki I gasped',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 204,
#   'language': 'en'},
#  {'content': "@deepadoc @IshitaYadav That's getting worst now",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 205,
#   'language': 'en'},
#  {'content': '@Lizkthequeen @EstherBirungi4 I’m fine dear. You? \nHaza ndimu mpora mpora',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 206,
#   'language': 'en'},
#  {'content': '@YG_Drag @VIZMedia @HxHSource I THOUGHT I WAS THE ONLY ONE',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 207,
#   'language': 'en'},
#  {'content': 'See my gf and spoil the homies https://t.co/KjcNLHrKTq',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 208,
#   'language': 'en'},
#  {'content': '@HakuPamfer Man that’s awful :(',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 209,
#   'language': 'en'},
#  {'content': '@Mechagaikotsu @Thesixth_pulsar @Grimlock4pres The HG of it is good though',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 210,
#   'language': 'en'},
#  {'content': '@queendayj I Miss You Too❤️😘 &amp; Headed To Get A Pedicure',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 211,
#   'language': 'en'},
#  {'content': 'Dude said Da Baby’s verse bout to slap 💀💀 https://t.co/1omnCdGYDq',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 212,
#   'language': 'en'},
#  {'content': '@GovMikeHuckabee @realDonaldTrump What an evil sick human. Black heart',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 213,
#   'language': 'en'},
#  {'content': 'Weed a clock',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 214,
#   'language': 'en'},
#  {'content': '@_jwilliams_____ Be safe bro',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 215,
#   'language': 'en'},
#  {'content': '@kommandostore Perfect! For those warzone medical applications where it’s death or ‘attach directly into your Femur’',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 216,
#   'language': 'en'},
#  {'content': "@Foxy_Cosplay I love her. She's everything ive ever wanted to be. Kind, but doesn't let people walk on her.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 217,
#   'language': 'en'},
#  {'content': 'I don’t care what y’all say I’m about to catch one of these cheap flights somewhere 👀\U0001f974😂 https://t.co/QLTuFg0S6Y',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 218,
#   'language': 'en'},
#  {'content': 'Love you my Hero @DanAuito 💯💯☘️ https://t.co/ljaW9PQqeY',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 219,
#   'language': 'en'},
#  {'content': '@Mechagaikotsu @Thesixth_pulsar @Grimlock4pres The HG of it is good though',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 220,
#   'language': 'en'},
#  {'content': '@queendayj I Miss You Too❤️😘 &amp; Headed To Get A Pedicure',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 221,
#   'language': 'en'},
#  {'content': 'Dude said Da Baby’s verse bout to slap 💀💀 https://t.co/1omnCdGYDq',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 222,
#   'language': 'en'},
#  {'content': '@GovMikeHuckabee @realDonaldTrump What an evil sick human. Black heart',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 223,
#   'language': 'en'},
#  {'content': 'Weed a clock',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 224,
#   'language': 'en'},
#  {'content': '@_jwilliams_____ Be safe bro',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 225,
#   'language': 'en'},
#  {'content': '@kommandostore Perfect! For those warzone medical applications where it’s death or ‘attach directly into your Femur’',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 226,
#   'language': 'en'},
#  {'content': "@Foxy_Cosplay I love her. She's everything ive ever wanted to be. Kind, but doesn't let people walk on her.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 227,
#   'language': 'en'},
#  {'content': 'I don’t care what y’all say I’m about to catch one of these cheap flights somewhere 👀\U0001f974😂 https://t.co/QLTuFg0S6Y',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 228,
#   'language': 'en'},
#  {'content': 'Love you my Hero @DanAuito 💯💯☘️ https://t.co/ljaW9PQqeY',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 229,
#   'language': 'en'},
#  {'content': '@Mechagaikotsu @Thesixth_pulsar @Grimlock4pres The HG of it is good though',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 230,
#   'language': 'en'},
#  {'content': '@queendayj I Miss You Too❤️😘 &amp; Headed To Get A Pedicure',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 231,
#   'language': 'en'},
#  {'content': 'Dude said Da Baby’s verse bout to slap 💀💀 https://t.co/1omnCdGYDq',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 232,
#   'language': 'en'},
#  {'content': '@GovMikeHuckabee @realDonaldTrump What an evil sick human. Black heart',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 233,
#   'language': 'en'},
#  {'content': 'Weed a clock',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 234,
#   'language': 'en'},
#  {'content': '@_jwilliams_____ Be safe bro',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 235,
#   'language': 'en'},
#  {'content': '@kommandostore Perfect! For those warzone medical applications where it’s death or ‘attach directly into your Femur’',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 236,
#   'language': 'en'},
#  {'content': "@Foxy_Cosplay I love her. She's everything ive ever wanted to be. Kind, but doesn't let people walk on her.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 237,
#   'language': 'en'},
#  {'content': 'I don’t care what y’all say I’m about to catch one of these cheap flights somewhere 👀\U0001f974😂 https://t.co/QLTuFg0S6Y',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 238,
#   'language': 'en'},
#  {'content': 'Love you my Hero @DanAuito 💯💯☘️ https://t.co/ljaW9PQqeY',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 239,
#   'language': 'en'},
#  {'content': '@athalarsbryce Not telling you how to live your life, but do it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 240,
#   'language': 'en'},
#  {'content': "@yxiao1988 Yeah, that's true.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 241,
#   'language': 'en'},
#  {'content': 'do y’all know realize how shit like this sounds like https://t.co/MBRB4di1eL',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 242,
#   'language': 'en'},
#  {'content': '@Kytrex ur not funny',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 243,
#   'language': 'en'},
#  {'content': 'Either way you getting shot at😂 https://t.co/KTXDGh7HdN',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 244,
#   'language': 'en'},
#  {'content': 'Happy Birthday pretty pretty girl 🤤\U0001f970❤️ https://t.co/kr1mZIzBiQ',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 245,
#   'language': 'en'},
#  {'content': '@auth_ntic @OfficialAggro YESSIRRRRRRRRRRRRRR ily',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 246,
#   'language': 'en'},
#  {'content': 'Babey 💙💙💙💙💙💙💙💙💙💙\n\ni ordered Commission page doll from https://t.co/U7AqNzzRBi and i really really love this so much… https://t.co/5jQ7ppc42q',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 247,
#   'language': 'en'},
#  {'content': 'Strawberry kee you dia😏 https://t.co/VmdhPm0nd2',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 248,
#   'language': 'en'},
#  {'content': '@cjafterdark You dare diss Ellen DeGeneres\n\nShe was a fish once',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 249,
#   'language': 'en'},
#  {'content': '@athalarsbryce Not telling you how to live your life, but do it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 250,
#   'language': 'en'},
#  {'content': "@yxiao1988 Yeah, that's true.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 251,
#   'language': 'en'},
#  {'content': 'do y’all know realize how shit like this sounds like https://t.co/MBRB4di1eL',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 252,
#   'language': 'en'},
#  {'content': '@Kytrex ur not funny',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 253,
#   'language': 'en'},
#  {'content': 'Either way you getting shot at😂 https://t.co/KTXDGh7HdN',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 254,
#   'language': 'en'},
#  {'content': 'Happy Birthday pretty pretty girl 🤤\U0001f970❤️ https://t.co/kr1mZIzBiQ',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 255,
#   'language': 'en'},
#  {'content': '@auth_ntic @OfficialAggro YESSIRRRRRRRRRRRRRR ily',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 256,
#   'language': 'en'},
#  {'content': 'Babey 💙💙💙💙💙💙💙💙💙💙\n\ni ordered Commission page doll from https://t.co/U7AqNzzRBi and i really really love this so much… https://t.co/5jQ7ppc42q',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 257,
#   'language': 'en'},
#  {'content': 'Strawberry kee you dia😏 https://t.co/VmdhPm0nd2',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 258,
#   'language': 'en'},
#  {'content': '@cjafterdark You dare diss Ellen DeGeneres\n\nShe was a fish once',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 259,
#   'language': 'en'},
#  {'content': '@athalarsbryce Not telling you how to live your life, but do it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 260,
#   'language': 'en'},
#  {'content': "@yxiao1988 Yeah, that's true.",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 261,
#   'language': 'en'},
#  {'content': 'do y’all know realize how shit like this sounds like https://t.co/MBRB4di1eL',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 262,
#   'language': 'en'},
#  {'content': '@Kytrex ur not funny',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 263,
#   'language': 'en'},
#  {'content': 'Either way you getting shot at😂 https://t.co/KTXDGh7HdN',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 264,
#   'language': 'en'},
#  {'content': 'Happy Birthday pretty pretty girl 🤤\U0001f970❤️ https://t.co/kr1mZIzBiQ',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 265,
#   'language': 'en'},
#  {'content': '@auth_ntic @OfficialAggro YESSIRRRRRRRRRRRRRR ily',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 266,
#   'language': 'en'},
#  {'content': 'Babey 💙💙💙💙💙💙💙💙💙💙\n\ni ordered Commission page doll from https://t.co/U7AqNzzRBi and i really really love this so much… https://t.co/5jQ7ppc42q',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 267,
#   'language': 'en'},
#  {'content': 'Strawberry kee you dia😏 https://t.co/VmdhPm0nd2',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 268,
#   'language': 'en'},
#  {'content': '@cjafterdark You dare diss Ellen DeGeneres\n\nShe was a fish once',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 269,
#   'language': 'en'},
#  {'content': '@sage_wmn The latter part of this thread!Trump for President in Russia 2020',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 270,
#   'language': 'en'},
#  {'content': '@PaxtonRoadUpper But anyone worried can get on the magic bus , that’s the last one I promise!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 271,
#   'language': 'en'},
#  {'content': '@speedwaffle I had the same on my 98/99 shirt but someone pinched it. \U0001f92c\U0001f92c',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 272,
#   'language': 'en'},
#  {'content': 'I have the tendency to judge people based on their facial expressions and their body language.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 273,
#   'language': 'en'},
#  {'content': "I just earned the 'Land of the Free  (Level 40)' badge on @untappd! https://t.co/pb6jdlOK2J",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 274,
#   'language': 'en'},
#  {'content': '@SlumpBuster1978 @GunnelsWarren Ok yeah the politicians they own forced them to take it.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 275,
#   'language': 'en'},
#  {'content': '@TMZ Why do they hate each other? Aren’t they both LA teams?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 276,
#   'language': 'en'},
#  {'content': '@AWorldOutOfMind @PianistRichard Agree, fuck religion.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 277,
#   'language': 'en'},
#  {'content': '@Thola_md Goodnight ❤❤.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 278,
#   'language': 'en'},
#  {'content': '@realDonaldTrump 😁👍Absolutely!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 279,
#   'language': 'en'},
#  {'content': '@sage_wmn The latter part of this thread!Trump for President in Russia 2020',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 280,
#   'language': 'en'},
#  {'content': '@PaxtonRoadUpper But anyone worried can get on the magic bus , that’s the last one I promise!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 281,
#   'language': 'en'},
#  {'content': '@speedwaffle I had the same on my 98/99 shirt but someone pinched it. \U0001f92c\U0001f92c',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 282,
#   'language': 'en'},
#  {'content': 'I have the tendency to judge people based on their facial expressions and their body language.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 283,
#   'language': 'en'},
# ...
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 902,
#   'language': 'en'},
#  {'content': "@KellyannePolls  “It is not being contained. Do you  think it's being contained?”",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 903,
#   'language': 'en'},
#  {'content': 'Los Angeles Angels versus Cleveland Indians Baseball Live Stream Uk 09-Mar - USA - BASEBALL https://t.co/Ni88YoyWDv https://t.co/I0aYtGjcTt',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 904,
#   'language': 'en'},
#  {'content': 'Our Beta Site Is Up &amp; Live Now!\nhttps://t.co/GQgvgvKvgN',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 905,
#   'language': 'en'},
#  {'content': 'Dress shopping is exhausting dude',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 906,
#   'language': 'en'},
#  {'content': 'Chicago White Sox vs Cincinnati Reds Baseball Streaming Live 09 MARCH USA - BASEBALL https://t.co/pivhnAaO9o https://t.co/UnTo8E4DU4',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 907,
#   'language': 'en'},
#  {'content': 'Cleveland Indians vs San Francisco Giants Baseball Stream Live 1080p 09-Mar - USA - BASEBALL https://t.co/GQDb1WPMUR https://t.co/YBbtjw3GVH',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 908,
#   'language': 'en'},
#  {'content': 'Chievo versus Cosenza Football Live Streams Free 09-Mar - Football B - Italy https://t.co/p1inZkz62G https://t.co/lQR1t3uMbi',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 909,
#   'language': 'en'},
#  {'content': '53099EC9 :Battle ID\nI need backup!\nLvl 100 Colossus Omega\nhttps://t.co/QgO1TFVHRn',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 910,
#   'language': 'en'},
#  {'content': '@mayadykes HONESTLY!!!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 911,
#   'language': 'en'},
#  {'content': 'Do any of y’all collect/trade animal crossing amiibo cards?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 912,
#   'language': 'en'},
#  {'content': '@malec_larry thats right plus i believe mewgulf know exactly what they’re doing. mew tests result are negative for… https://t.co/mFREe5ZCxU',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 913,
#   'language': 'en'},
#  {'content': 'no problematic behavior no cringeyness no fandom drama just txt and moas vibing',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 914,
#   'language': 'en'},
#  {'content': '@bocacmb good luck !!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 915,
#   'language': 'en'},
#  {'content': '#BTSARMY\xa0 if you \n\n- Don’t love all members\n- Disrespect/hate any member\n- Tell ANY member to leave \n- Demand they… https://t.co/yjhkRnAyV8',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 916,
#   'language': 'en'},
#  {'content': '@SenMikeLee @realDonaldTrump With the 5 Eyes not cooperating fully with you it seems foolish to throw the info you… https://t.co/W7uVbjaolc',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 917,
#   'language': 'en'},
#  {'content': 'i feel it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 918,
#   'language': 'en'},
#  {'content': 'Come on Barbie, let’s go party @ my palace  💕 @ The Don CeSar https://t.co/RUk9ZWmLOm',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 919,
#   'language': 'en'},
#  {'content': '53099EC9 :Battle ID\nI need backup!\nLvl 100 Colossus Omega\nhttps://t.co/QgO1TFVHRn',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 920,
#   'language': 'en'},
#  {'content': '@mayadykes HONESTLY!!!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 921,
#   'language': 'en'},
#  {'content': 'Do any of y’all collect/trade animal crossing amiibo cards?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 922,
#   'language': 'en'},
#  {'content': '@malec_larry thats right plus i believe mewgulf know exactly what they’re doing. mew tests result are negative for… https://t.co/mFREe5ZCxU',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 923,
#   'language': 'en'},
#  {'content': 'no problematic behavior no cringeyness no fandom drama just txt and moas vibing',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 924,
#   'language': 'en'},
#  {'content': '@bocacmb good luck !!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 925,
#   'language': 'en'},
#  {'content': '#BTSARMY\xa0 if you \n\n- Don’t love all members\n- Disrespect/hate any member\n- Tell ANY member to leave \n- Demand they… https://t.co/yjhkRnAyV8',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 926,
#   'language': 'en'},
#  {'content': '@SenMikeLee @realDonaldTrump With the 5 Eyes not cooperating fully with you it seems foolish to throw the info you… https://t.co/W7uVbjaolc',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 927,
#   'language': 'en'},
#  {'content': 'i feel it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 928,
#   'language': 'en'},
#  {'content': 'Come on Barbie, let’s go party @ my palace  💕 @ The Don CeSar https://t.co/RUk9ZWmLOm',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 929,
#   'language': 'en'},
#  {'content': '53099EC9 :Battle ID\nI need backup!\nLvl 100 Colossus Omega\nhttps://t.co/QgO1TFVHRn',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 930,
#   'language': 'en'},
#  {'content': '@mayadykes HONESTLY!!!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 931,
#   'language': 'en'},
#  {'content': 'Do any of y’all collect/trade animal crossing amiibo cards?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 932,
#   'language': 'en'},
#  {'content': '@malec_larry thats right plus i believe mewgulf know exactly what they’re doing. mew tests result are negative for… https://t.co/mFREe5ZCxU',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 933,
#   'language': 'en'},
#  {'content': 'no problematic behavior no cringeyness no fandom drama just txt and moas vibing',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 934,
#   'language': 'en'},
#  {'content': '@bocacmb good luck !!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 935,
#   'language': 'en'},
#  {'content': '#BTSARMY\xa0 if you \n\n- Don’t love all members\n- Disrespect/hate any member\n- Tell ANY member to leave \n- Demand they… https://t.co/yjhkRnAyV8',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 936,
#   'language': 'en'},
#  {'content': '@SenMikeLee @realDonaldTrump With the 5 Eyes not cooperating fully with you it seems foolish to throw the info you… https://t.co/W7uVbjaolc',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 937,
#   'language': 'en'},
#  {'content': 'i feel it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 938,
#   'language': 'en'},
#  {'content': 'Come on Barbie, let’s go party @ my palace  💕 @ The Don CeSar https://t.co/RUk9ZWmLOm',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 939,
#   'language': 'en'},
#  {'content': 'shut up i’m literally so scared rn LMFAOOO actually in tears i’m so dramatic',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 940,
#   'language': 'en'},
#  {'content': '@CarolSabikJaffe @Amy_Siskind *shrugs*\n\nI try my best ...',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 941,
#   'language': 'en'},
#  {'content': '@07georgiarose @BravoWWHL @BravoAndy @BravoTV @BelowDeck Yay! ♥️U!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 942,
#   'language': 'en'},
#  {'content': '@sopesandwich The duality this man has',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 943,
#   'language': 'en'},
#  {'content': '@kthangell_ Yeah',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 944,
#   'language': 'en'},
#  {'content': 'The story of my life... \nSomeone finish the lyric',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 945,
#   'language': 'en'},
#  {'content': 'I think I’ve definitely changed my mind about ever being a mom😣😕 https://t.co/8KMN9ahlNo',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 946,
#   'language': 'en'},
#  {'content': 'i wish i didnt always let my anger get the best of me :c',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 947,
#   'language': 'en'},
#  {'content': '@PublicMature Love the angle of the view',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 948,
#   'language': 'en'},
#  {'content': "smokin' my old enemies\nand i'm stoned\nand I got my weed",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 949,
#   'language': 'en'},
#  {'content': 'shut up i’m literally so scared rn LMFAOOO actually in tears i’m so dramatic',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 950,
#   'language': 'en'},
#  {'content': '@CarolSabikJaffe @Amy_Siskind *shrugs*\n\nI try my best ...',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 951,
#   'language': 'en'},
#  {'content': '@07georgiarose @BravoWWHL @BravoAndy @BravoTV @BelowDeck Yay! ♥️U!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 952,
#   'language': 'en'},
#  {'content': '@sopesandwich The duality this man has',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 953,
#   'language': 'en'},
#  {'content': '@kthangell_ Yeah',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 954,
#   'language': 'en'},
#  {'content': 'The story of my life... \nSomeone finish the lyric',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 955,
#   'language': 'en'},
#  {'content': 'I think I’ve definitely changed my mind about ever being a mom😣😕 https://t.co/8KMN9ahlNo',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 956,
#   'language': 'en'},
#  {'content': 'i wish i didnt always let my anger get the best of me :c',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 957,
#   'language': 'en'},
#  {'content': '@PublicMature Love the angle of the view',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 958,
#   'language': 'en'},
#  {'content': "smokin' my old enemies\nand i'm stoned\nand I got my weed",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 959,
#   'language': 'en'},
#  {'content': 'shut up i’m literally so scared rn LMFAOOO actually in tears i’m so dramatic',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 960,
#   'language': 'en'},
#  {'content': '@CarolSabikJaffe @Amy_Siskind *shrugs*\n\nI try my best ...',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 961,
#   'language': 'en'},
#  {'content': '@07georgiarose @BravoWWHL @BravoAndy @BravoTV @BelowDeck Yay! ♥️U!',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 962,
#   'language': 'en'},
#  {'content': '@sopesandwich The duality this man has',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 963,
#   'language': 'en'},
#  {'content': '@kthangell_ Yeah',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 964,
#   'language': 'en'},
#  {'content': 'The story of my life... \nSomeone finish the lyric',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 965,
#   'language': 'en'},
#  {'content': 'I think I’ve definitely changed my mind about ever being a mom😣😕 https://t.co/8KMN9ahlNo',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 966,
#   'language': 'en'},
#  {'content': 'i wish i didnt always let my anger get the best of me :c',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 967,
#   'language': 'en'},
#  {'content': '@PublicMature Love the angle of the view',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 968,
#   'language': 'en'},
#  {'content': "smokin' my old enemies\nand i'm stoned\nand I got my weed",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 969,
#   'language': 'en'},
#  {'content': '@StaTay24 Damn fr son ? Mines good 😂😂😂 https://t.co/V46AlBkpXh',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 970,
#   'language': 'en'},
#  {'content': "@NicoleRuseCFC Mehhh not a massive fan of normal ones tbh, like they're nice yeah but not elite level IMO",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 971,
#   'language': 'en'},
#  {'content': '@doschwab I hate her',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 972,
#   'language': 'en'},
#  {'content': '@7Paper_Rings Yes I love it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 973,
#   'language': 'en'},
#  {'content': '@ClaremontRun @shorttyknows @JCoopstergold @Columbia penciled paged faxed to him piecemeal, making it difficult to… https://t.co/zjWOfuyigU',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 974,
#   'language': 'en'},
#  {'content': '@tsherrygeo Correlation and pawsation?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 975,
#   'language': 'en'},
#  {'content': '@unlandedgentry I need a lunch with @maykcobb',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 976,
#   'language': 'en'},
#  {'content': '@qtzyuki HELP I DIDNT EVEN NOTICE',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 977,
#   'language': 'en'},
#  {'content': 'LINK ANYONE???',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 978,
#   'language': 'en'},
#  {'content': '@_nym3ria Guy needs put in a padded cell.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 979,
#   'language': 'en'},
#  {'content': '@StaTay24 Damn fr son ? Mines good 😂😂😂 https://t.co/V46AlBkpXh',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 980,
#   'language': 'en'},
#  {'content': "@NicoleRuseCFC Mehhh not a massive fan of normal ones tbh, like they're nice yeah but not elite level IMO",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 981,
#   'language': 'en'},
#  {'content': '@doschwab I hate her',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 982,
#   'language': 'en'},
#  {'content': '@7Paper_Rings Yes I love it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 983,
#   'language': 'en'},
#  {'content': '@ClaremontRun @shorttyknows @JCoopstergold @Columbia penciled paged faxed to him piecemeal, making it difficult to… https://t.co/zjWOfuyigU',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 984,
#   'language': 'en'},
#  {'content': '@tsherrygeo Correlation and pawsation?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 985,
#   'language': 'en'},
#  {'content': '@unlandedgentry I need a lunch with @maykcobb',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 986,
#   'language': 'en'},
#  {'content': '@qtzyuki HELP I DIDNT EVEN NOTICE',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 987,
#   'language': 'en'},
#  {'content': 'LINK ANYONE???',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 988,
#   'language': 'en'},
#  {'content': '@_nym3ria Guy needs put in a padded cell.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 989,
#   'language': 'en'},
#  {'content': '@StaTay24 Damn fr son ? Mines good 😂😂😂 https://t.co/V46AlBkpXh',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 990,
#   'language': 'en'},
#  {'content': "@NicoleRuseCFC Mehhh not a massive fan of normal ones tbh, like they're nice yeah but not elite level IMO",
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 991,
#   'language': 'en'},
#  {'content': '@doschwab I hate her',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 992,
#   'language': 'en'},
#  {'content': '@7Paper_Rings Yes I love it',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 993,
#   'language': 'en'},
#  {'content': '@ClaremontRun @shorttyknows @JCoopstergold @Columbia penciled paged faxed to him piecemeal, making it difficult to… https://t.co/zjWOfuyigU',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 994,
#   'language': 'en'},
#  {'content': '@tsherrygeo Correlation and pawsation?',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 995,
#   'language': 'en'},
#  {'content': '@unlandedgentry I need a lunch with @maykcobb',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 996,
#   'language': 'en'},
#  {'content': '@qtzyuki HELP I DIDNT EVEN NOTICE',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 997,
#   'language': 'en'},
#  {'content': 'LINK ANYONE???',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 998,
#   'language': 'en'},
#  {'content': '@_nym3ria Guy needs put in a padded cell.',
#   'contenttype': 'text/plain',
#   'created': 0,
#   'id': 999,
#   'language': 'en'},
#  ...]

# %%
with open('data.json', 'w') as outfile:
    json.dump({'contentItems': dlist}, outfile,indent=4)

# %% [markdown]
# ### Working with demo data of 5 real tweets to figure out if Criminal intent is discovered or not
# ### Reading data from demo file and converting it into .json

# %%
import pandas as pd
df_demo=pd.read_csv("demodata.csv")
df_demo
# Out:
#               User       Location  \
# 0           atxleb            NaN
# 1   ShayneOfficial            NaN
# 2       JamesJgm26            NaN
# 3      VerucaMarie            NaN
# 4  Her_Masterpiece  New York, USA
#
#                                                Tweet
# 0  @theinstantwin @JKDAnthony10 @grantstern @TheD...
# 1  @SailorZZtar It’s actually cheaper to eat on t...
# 2    I will kill trump just to piss off the Russians
# 3  @DJSlash always. We had to put the rock to sle...
# 4  Just passed by a house with their icicle light...

# %%
#create a list of dictionaries to later import it into json format that is accepted by Watson
df=df_demo
d={}#The dictionary
dlist=[]#The list to append the dictionary to

for i in df.itertuples():
    d={}
    d['content']=i[3]
    d['contenttype']="text/plain"
    d['created']= 0
    d['id']= i[0]
    d['language']= "en"
    dlist.append(d)
    print(d,"\n")
# Out:
# {'content': '@theinstantwin @JKDAnthony10 @grantstern @TheDemCoalition Because they’d be prosecuting government officials?', 'contenttype': 'text/plain', 'created': 0, 'id': 0, 'language': 'en'}
#
# {'content': '@SailorZZtar It’s actually cheaper to eat on the right. That’s multiple days worth of food. The McD’s is just one meal during the day', 'contenttype': 'text/plain', 'created': 0, 'id': 1, 'language': 'en'}
#
# {'content': 'I will kill trump just to piss off the Russians', 'contenttype': 'text/plain', 'created': 0, 'id': 2, 'language': 'en'}
#
# {'content': '@DJSlash always. We had to put the rock to sleep early tonight because Layla was really tired.', 'contenttype': 'text/plain', 'created': 0, 'id': 3, 'language': 'en'}
#
# {'content': 'Just passed by a house with their icicle lights and wreath still up.', 'contenttype': 'text/plain', 'created': 0, 'id': 4, 'language': 'en'}

# %%
#Dumping data in json format
with open('datademo.json', 'w') as outfile:
    json.dump({'contentItems': dlist}, outfile,indent=4)
